# %% [markdown]
# # Assignment 3: Machine Translation
#
# In this assignment you will implement a LSTM based sequence-to-sequence model for machine translation.
# * We have provided an implementation of the encoder. You will need to implement an LSTM based decoder and then use it to train a basic sequence-to-sequence model.
# * Next, you will extend the decoder with attention and implement beam search decoding (we have provided a greedy decoder as reference).
# * Lastly you can try to improve the model using extensions such as a back translation or data augmentation.
#
# **Warning**: Attention and beam search can be tricky to implement. We expect this assignment to take longer than the CRF one. Please don't start the day before it is due!
#
# We will use the Multi30k for this assignment which consists of 30k German and English sentences.
#
# **Note**: When implementing beam search, to keep things simple we will not use batching (beam search on one sentence at a time). However, for implementing the decoders, please use batching.
#
# **Grading Rubric**
# - 70% results
#   - 20% seq2seq_predictions_baseline.json (meets target)
#   - 20% seq2seq_predictions_attention.json (meets target)
#   - 20% beam_seqs.json (correctness)
#   - 10% seq2seq_predictions_attention.json (improvement)
#
# - 30% writeup
#  - 12.5% clarity
#  - 12.5% correctness
#  - 5% interestingness of ideas

# %% [markdown]
# ## Imports
#
# Feel free to add other libraries here (that don't already implement what you are supposed to!)

# %%
# %%capture
# !pip install --upgrade sacrebleu sentencepiece gdown
# Standard library imports
import json
import math
import random

# Third party imports
import matplotlib.pyplot as plt
import numpy as np
import sacrebleu
import sentencepiece
import torch
import torch.nn as nn
import torch.nn.functional as F
import tqdm.notebook

# %% [markdown]
# Before proceeding, let's verify that we're connected to a GPU runtime and that `torch` can detect the GPU. Manage this by go to the Runtime tab in your colab.
# We'll define a variable `device` here to use throughout the code so that we can easily change to run on CPU for debugging.
#
# Note that if you use "CPU" training time would be much slower depending on the CPU (likely 20 times slower). So use of GPU is recommended, be sure to manage your GPU so that it doesn't run out of quota.

# %%
try:
    assert torch.cuda.is_available()
    device = torch.device("cuda")
except:
    device = torch.device("cpu")
print("Using device:", device)
# Out:
# Using device: cuda

# %% [markdown]
# ## Data
#
# The data for this assignment comes from the [Multi30K dataset](https://arxiv.org/abs/1605.00459), which contains English and German captions for images from Flickr. We can download it using `gdown`. We use the Multi30K dataset because it is simpler than standard translation benchmark datasets and allows for models to be trained and evaluated in a matter of minutes rather than days using a GPU.
#
# We will be translating from German to English in this assignment, but the same techniques apply equally well to any language pair.
#
#
#
# **You do not need to modify anything in this section.**

# %% [markdown]
# First let's download the data and visualize some of the data:

# %%
# !gdown 1ll4fDiPLQ0u9osdtSlsUcehK_p_2dykV
# !gdown 1OEBVpX9F2FX0Mqj17jOWJKI2efUN_HBR
# !gdown 1zZF8EXtzcd3oXSGEfyKywkSMosX_T6Jo
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ll4fDiPLQ0u9osdtSlsUcehK_p_2dykV
# To: /content/training_data.json
# 100% 4.28M/4.28M [00:00<00:00, 121MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1OEBVpX9F2FX0Mqj17jOWJKI2efUN_HBR
# To: /content/validation_data.json
# 100% 152k/152k [00:00<00:00, 67.4MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1zZF8EXtzcd3oXSGEfyKywkSMosX_T6Jo
# To: /content/test_data.json
# 100% 80.2k/80.2k [00:00<00:00, 126MB/s]

# %%
with open("training_data.json","r") as f:
    training_data = json.load(f)
with open("validation_data.json","r") as f:
    validation_data = json.load(f)
with open("test_data.json","r") as f:
    test_data = json.load(f)
print("Number of training examples:", len(list(training_data)))
print("Number of validation examples:", len(list(validation_data)))
print("Number of test examples:", len(list(test_data)))
print()

for example in training_data[:10]:
  print(example[0])
  print(example[1])
  print()
# Out:
# Number of training examples: 29001
# Number of validation examples: 1015
# Number of test examples: 1000
#
# Zwei junge weiße Männer sind im Freien in der Nähe vieler Büsche.
# Two young, White males are outside near many bushes.
#
# Mehrere Männer mit Schutzhelmen bedienen ein Antriebsradsystem.
# Several men in hard hats are operating a giant pulley system.
#
# Ein kleines Mädchen klettert in ein Spielhaus aus Holz.
# A little girl climbing into a wooden playhouse.
#
# Ein Mann in einem blauen Hemd steht auf einer Leiter und putzt ein Fenster.
# A man in a blue shirt is standing on a ladder cleaning a window.
#
# Zwei Männer stehen am Herd und bereiten Essen zu.
# Two men are at the stove preparing food.
#
# Ein Mann in grün hält eine Gitarre, während der andere Mann sein Hemd ansieht.
# A man in green holds a guitar while the other man observes his shirt.
#
# Ein Mann lächelt einen ausgestopften Löwen an.
# A man is smiling at a stuffed lion
#
# Ein schickes Mädchen spricht mit dem Handy während sie langsam die Straße entlangschwebt.
# A trendy girl talking on her cellphone while gliding slowly down the street.
#
# Eine Frau mit einer großen Geldbörse geht an einem Tor vorbei.
# A woman with a large purse is walking by a gate.
#
# Jungen tanzen mitten in der Nacht auf Pfosten.
# Boys dancing on poles in the middle of the night.

# %% [markdown]
# Vocabulary:
# Now We can use `sentencepiece` to create a joint German-English subword vocabulary from the training corpus. Subwords are words being divided into smaller pieces. They usually provide better performance since it takes advantages over common section among different words (see more at https://huggingface.co/docs/transformers/en/tokenizer_summary) and it handles Out of Vocabulary (OOV) words a lot better (https://blog.octanove.org/guide-to-subword-tokenization/). Because the number of training examples is small, we choose a smaller vocabulary size than would be used for large-scale NMT.

# %% [markdown]
# Let's download the English and German training corpous to construct our vocabulary. The two files downloaded here contains English and German sentences are from the training data we downloaded above but are decoupled to be used for the `sentencepiece` library.

# %%
# !gdown 1bO7SVCjvVzp__ibwED8wbMRSiJQNNP52
# !gdown 1A2w-F6kmUXNtuFtG2qdpfw0dx2Mk7phR
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1bO7SVCjvVzp__ibwED8wbMRSiJQNNP52
# To: /content/train.en
# 100% 1.80M/1.80M [00:00<00:00, 38.9MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1A2w-F6kmUXNtuFtG2qdpfw0dx2Mk7phR
# To: /content/train.de
# 100% 2.11M/2.11M [00:00<00:00, 174MB/s]

# %% [markdown]
# We will use a unigram language model for subword segmentation (https://aclanthology.org/P18-1007.pdf). There are other techniques such as using BPE and or using characters, but we won't explore into them here (you can consider trying different subword strategies to improve your model later in the improvement section).

# %%
args = {
    "pad_id": 0,
    "bos_id": 1,
    "eos_id": 2,
    "unk_id": 3,
    "input": "train.de,train.en",
    "vocab_size": 8000,
    "model_prefix": "Multi30k",
    
    ################### Adding Improvement : Uncomment the following line to do BPE #####################
    "model_type": "bpe",
    #####################################################################################################
}
combined_args = " ".join(
    "--{}={}".format(key, value) for key, value in args.items())
sentencepiece.SentencePieceTrainer.Train(combined_args)

# %% [markdown]
# This creates two files: `Multi30k.model` and `Multi30k.vocab`. The first is a binary file containing the relevant data for the vocabulary. The second is a human-readable listing of each subword and its associated score. The score is the logged probability of the subword in the corpus. A higher score means that subword appears more frequently in the corpus.
#
# `sentencepiece` trainer basically finds a set of those subwords such that their joint probabily maximaizes over the corpus. How do you find the correct segmentation of words to subword such that you can maximize this joint probability becomes the question. This can be done by using a Viterbi algorithm (you implemented last assignment!). You don't need to know exactly how this is done but if you are intrested you can look into this [paper](https://aclanthology.org/P18-1007.pdf).

# %% [markdown]
# You can preveiw some of the word scores:

# %%
# !head -n 30 Multi30k.vocab
# Out:
# <pad>	0
# <s>	0
# </s>	0
# <unk>	0
# .	-2.72718
# ▁a	-3.21357
# ▁in	-3.43973
# m	-3.78503
# ▁eine	-3.82141
# ▁A	-3.86856
# s	-4.06457
# ▁Ein	-4.11399
# ,	-4.20405
# ▁the	-4.35217
# ▁und	-4.5704
# ▁mit	-4.57911
# ▁auf	-4.58144
# ▁on	-4.65674
# n	-4.67038
# ▁Mann	-4.70521
# ▁is	-4.73988
# ▁man	-4.75331
# ▁and	-4.76404
# ▁	-4.76512
# ing	-4.8072
# ▁of	-4.83344
# ▁einer	-4.86421
# ▁with	-4.93426
# ▁Eine	-4.98902
# ▁ein	-5.126

# %% [markdown]
# As we can see, the vocabulary consists of four special tokens (`<pad>` for padding, `<s>` for beginning of sentence (BOS), `</s>` for end of sentence (EOS), `<unk>` for unknown) and a mixture of German and English words and subwords. In order to ensure reversability, word boundaries are encoded with a special unicode character "▁" (U+2581).

# %% [markdown]
# To use the vocabulary, we first need to load it from the binary file produced above.

# %%
vocab = sentencepiece.SentencePieceProcessor()
vocab.Load("Multi30k.model")
# Out:
# True

# %% [markdown]
# The vocabulary object includes a number of methods for working with full sequences or individual pieces. We explore the most relevant ones below. A complete interface can be found on [GitHub](https://github.com/google/sentencepiece/tree/master/python#usage) for reference.

# %%
print("Vocabulary size:", vocab.GetPieceSize())
print()

for example in training_data[:3]:
  sentence = example[1]
  pieces = vocab.EncodeAsPieces(sentence)
  indices = vocab.EncodeAsIds(sentence)
  print(sentence)
  print(pieces)
  print(vocab.DecodePieces(pieces))
  print(indices)
  print(vocab.DecodeIds(indices))
  print()

piece = vocab.EncodeAsPieces("the")[0]
index = vocab.PieceToId(piece)
print(piece)
print(index)
print(vocab.IdToPiece(index))
# Out:
# Vocabulary size: 8000
#
# Two young, White males are outside near many bushes.
# ['▁Two', '▁young', ',', '▁White', '▁males', '▁are', '▁outside', '▁near', '▁many', '▁bushes', '.']
# Two young, White males are outside near many bushes.
# [42, 54, 12, 2889, 2225, 36, 127, 173, 815, 3513, 4]
# Two young, White males are outside near many bushes.
#
# Several men in hard hats are operating a giant pulley system.
# ['▁Se', 'veral', '▁men', '▁in', '▁hard', '▁hats', '▁are', '▁operating', '▁a', '▁g', 'iant', '▁pull', 'e', 'y', '▁s', 'y', 'ste', 'm', '.']
# Several men in hard hats are operating a giant pulley system.
# [298, 240, 73, 6, 712, 730, 36, 3106, 5, 631, 1679, 583, 32, 96, 552, 96, 1076, 7, 4]
# Several men in hard hats are operating a giant pulley system.
#
# A little girl climbing into a wooden playhouse.
# ['▁A', '▁little', '▁girl', '▁climbing', '▁in', 'to', '▁a', '▁wooden', '▁play', 'house', '.']
# A little girl climbing into a wooden playhouse.
# [9, 132, 66, 500, 6, 112, 5, 542, 245, 4599, 4]
# A little girl climbing into a wooden playhouse.
#
# ▁the
# 13
# ▁the

# %% [markdown]
# We define some constants here for the first three special tokens that you may find useful in the following sections.

# %%
pad_id = vocab.PieceToId("<pad>")
bos_id = vocab.PieceToId("<s>")
eos_id = vocab.PieceToId("</s>")
print(f"<pad>: {pad_id}, <s>: {bos_id}, </s>: {eos_id}")
# Out:
# <pad>: 0, <s>: 1, </s>: 2

# %% [markdown]
# Note that these tokens will be stripped from the output when converting from word pieces to text. This may be helpful when implementing greedy search and beam search.

# %%
sentence = training_data[0][1]
indices = vocab.EncodeAsIds(sentence)
indices_augmented = [bos_id] + indices + [eos_id, pad_id, pad_id, pad_id]
print(vocab.DecodeIds(indices))
print(vocab.DecodeIds(indices_augmented))
print(vocab.DecodeIds(indices) == vocab.DecodeIds(indices_augmented))
# Out:
# Two young, White males are outside near many bushes.
# Two young, White males are outside near many bushes.
# True

# %% [markdown]
# Code for saving your results for submission. You don't have to read this.

# %%
# Please do not change the code below
def generate_predictions_file_for_submission(filepath, model, dataset, method, batch_size=64):
    assert method in {"greedy", "beam"}
    source_sentences = [example[0] for example in dataset]
    model.eval()
    predictions = []
    with torch.no_grad():
      for start_index in range(0, len(source_sentences), batch_size):
        if method == "greedy":
          prediction_batch = predict_greedy(
              model, source_sentences[start_index:start_index + batch_size])
          prediction_batch = [[x] for x in prediction_batch]
        else:
          prediction_batch = predict_beam(
              model, source_sentences[start_index:start_index + batch_size])
        predictions.extend(prediction_batch)
    with open(filepath, "w") as outfile:
        json.dump(predictions, outfile, indent=2)
    print("Finished writing predictions to {}.".format(filepath))

# %% [markdown]
# ## Seq2Seq Machine Translation Model
#
# Now let's implement a sequence-to-sequence machine translation model. We will first implement an `Encode` and an `Decode` method and then put these together in a `Seq2seqBaseline` class.
#
# We have implemented the `Encode` method below which encodes input sequences using a bi-directional LSTM. A bi-LSTM consists of a stack of two LSTM networks, one which processes the sequence in forward direction and another which processes the sequence in reverse direction. The output hidden states from both are concatenated to get the representations at each position. Further, we average the final states in either direction before returning.

# %% [markdown]
# ### **Implementation Task \# 1**
#
# Let's begin by defining a batch iterator for the training data. Given a dataset and a batch size, it will iterate over the dataset and yield pairs of tensors containing the subword indices for the source and target sentences in the batch, respectively.  We filled in `make_batch` below. It is advised to read the code below to get a sense of how sentences are tokenized and batched.
#
# **Note**: Maybe a little different from previous assignments, we are keeping batch_size to be the **2nd** dimension.

# %%
def make_batch(sentences):
  """Convert a list of sentences into a batch of subword indices.

  Args:
    sentences: A list of sentences, each of which is a string.

  Returns:
    A LongTensor of size (max_sequence_length, batch_size) containing the
    subword indices for the sentences, where max_sequence_length is the length
    of the longest sentence as encoded by the subword vocabulary and batch_size
    is the number of sentences in the batch. A beginning-of-sentence token
    should be included before each sequence, and an end-of-sentence token should
    be included after each sequence. Empty slots at the end of shorter sequences
    should be filled with padding tokens. The tensor should be located on the
    device defined at the beginning of the notebook.
  """

  batch_indices = []
  for sentence in sentences:
    indices = vocab.EncodeAsIds(sentence)
    indices_augmented = [bos_id] + indices + [eos_id]
    indices_augmented = torch.LongTensor(indices_augmented)
    batch_indices.append(indices_augmented)

  batched_seq = torch.nn.utils.rnn.pad_sequence(batch_indices, padding_value=pad_id).to(device)
  return batched_seq

def make_batch_iterator(dataset, batch_size, shuffle=False):
  """Make a batch iterator that yields source-target pairs.

  Args:
    dataset: A torchtext dataset object.
    batch_size: An integer batch size.
    shuffle: A boolean indicating whether to shuffle the examples.

  Yields:
    Pairs of tensors constructed by calling the make_batch function on the
    source and target sentences in the current group of examples. The max
    sequence length can differ between the source and target tensor, but the
    batch size will be the same. The final batch may be smaller than the given
    batch size.
  """

  examples = list(dataset)
  if shuffle:
    random.shuffle(examples)

  for start_index in range(0, len(examples), batch_size):
    example_batch = examples[start_index:start_index + batch_size]
    source_sentences = [example[0] for example in example_batch]
    target_sentences = [example[1] for example in example_batch]
    yield make_batch(source_sentences), make_batch(target_sentences)

test_batch = make_batch(["a test input", "a longer input than the first"])
print("Example batch tensor:")
print(test_batch)
assert test_batch.shape[1] == 2
assert test_batch[0, 0] == bos_id
assert test_batch[0, 1] == bos_id
assert test_batch[-1, 0] == pad_id
assert test_batch[-1, 1] == eos_id
# Out:
# Example batch tensor:
# tensor([[   1,    1],
#         [   5,    5],
#         [3966,  354],
#         [   6,   60],
#         [ 236,    6],
#         [ 698,  236],
#         [   2,  698],
#         [   0, 5285],
#         [   0,   13],
#         [   0, 3759],
#         [   0,    2]], device='cuda:0')

# %% [markdown]
# Implement an LSTM based decoder below. The decoder should be similar to the encoder which is already implemented, except it will accept a `state` tuple with the initial values of the `h_n` and `c_n` states (which will be the final states from the encoder above). Also the inputs to the decoder will be embed using the same embedder from the encoder. We will also return the final state from the decoder since we will need it for inference later.

# %%
class Seq2seqBaseline(nn.Module):
  def __init__(self, hidden_dim, word_vector_dim, dropout,num_layers):
    super().__init__()
    """
    args:
      hidden_dim: hidden state size of LSTM
      word_vector_dim: size of the word embedding table
      dropout: this is applied to the output of the LSTM
    """
    ### Encoder Params. Please do not change these functions at all.
    self.dropout = nn.Dropout(dropout)
    # Embedding table over input vocabulary
    self.embedder = nn.Embedding(vocab.GetPieceSize(), word_vector_dim)
    self.lstm = nn.LSTM(word_vector_dim, hidden_dim, bidirectional=True, num_layers=num_layers)
    self.layer = nn.Linear(hidden_dim*num_layers*2, hidden_dim*num_layers)
    self.layer2 = nn.Linear(hidden_dim*num_layers*2, hidden_dim*num_layers)

    ### Decoder Params.
    self.dropout2 = nn.Dropout(dropout)
    self.lstm2 = nn.LSTM(word_vector_dim, hidden_dim, num_layers=2)
    self.output_layer2 = nn.Linear(hidden_dim, vocab.GetPieceSize())
    self.log_softmax_layer = nn.LogSoftmax(dim=2)

  def encode(self, source):
    """Encode the source batch using a bidirectional LSTM encoder.

    Args:
      source: An integer tensor with shape (max_source_sequence_length,
        batch_size) containing subword indices for the source sentences.

    Returns:
      A tuple with three elements:
        encoder_output: The output of the bidirectional LSTM with shape
          (max_source_sequence_length, batch_size, 2 * hidden_size).
        encoder_mask: A boolean tensor with shape (max_source_sequence_length,
          batch_size) indicating which encoder outputs correspond to padding
          tokens. Its elements should be True at positions corresponding to
          padding tokens and False elsewhere.
        encoder_hidden: The final hidden states of the bidirectional LSTM (after
          a suitable projection) that will be used to initialize the decoder.
          This should be a pair of tensors (h_n, c_n), each with shape
          (num_layers, batch_size, hidden_size). Note that the hidden state
          returned by the LSTM cannot be used directly. Its initial dimension is
          twice the required size because it contains state from two directions.

    The first two return values are not required for the baseline model and will
    only be used later in the attention model. If desired, they can be replaced
    with None for the initial implementation.
    """

    # Using packed sequences to more easily work
    # with the variable-length sequences represented by the source tensor.
    # See https://pytorch.org/docs/stable/nn.html#torch.nn.utils.rnn.PackedSequence.


    # Compute a tensor containing the length of each source sequence.
    lengths = torch.sum(source != pad_id, axis=0).cpu()

    seq_len, batch_size = source.size()

    # embedded_sentence: seq_len x batch_size x word_vector_dim
    embedded_sentence = self.embedder(source)

    # pack it for rnn input
    embedded_sentence = torch.nn.utils.rnn.pack_padded_sequence(embedded_sentence,lengths,enforce_sorted=False)

    # lstm_out: seq_len x batch_size x 2 * hidden_dim
    # h_n, c_n: num_lay*2 x batch_size x hidden_dim
    lstm_out, (h_n, c_n) = self.lstm(embedded_sentence)

    # Take average of states across forward and reverse directions.
    h_n = h_n.view(2, -1, batch_size, h_n.shape[-1]).sum(1)
    c_n = c_n.view(2, -1, batch_size, c_n.shape[-1]).sum(1)

    encoder_mask = source == pad_id

    lstm_out, lens_unpacked = torch.nn.utils.rnn.pad_packed_sequence(lstm_out)
    lstm_out = self.dropout(lstm_out)

    return lstm_out, encoder_mask,(h_n, c_n)



  def decode(self, decoder_input, initial_hidden, encoder_output, encoder_mask):
    """Run the decoder LSTM starting from an initial hidden state.

    The third and fourth arguments are not used in the baseline model, but are
    included for compatibility with the attention model in the next section.

    Args:
      decoder_input: An integer tensor with shape (max_decoder_sequence_length,
        batch_size) containing the subword indices for the decoder input. During
        evaluation, where decoding proceeds one step at a time, the initial
        dimension should be 1.
      initial_hidden: A pair of tensors (h_0, c_0) representing the initial
        state of the decoder, each with shape (num_layers, batch_size,
        hidden_size).
      encoder_output: The output of the encoder with shape
        (max_source_sequence_length, batch_size, 2 * hidden_size).
      encoder_mask: The output mask from the encoder with shape
        (max_source_sequence_length, batch_size). Encoder outputs at positions
        with a True value correspond to padding tokens and should be ignored.

    Returns:
      A tuple with three elements:
        log_probs: A tensor with shape (max_decoder_sequence_length, batch_size,
          vocab_size) containing scores for the next-word
          predictions at each position.
        decoder_hidden: A pair of tensors (h_n, c_n) with the same shape as
          initial_hidden representing the updated decoder state after processing
          the decoder input.
        attention_weights: This will be implemented later in the attention
          model, but in order to maintain compatible type signatures, we also
          include it here. This can be None or any other placeholder value.
    """

    # These arguments are not used in the baseline model.
    del encoder_output
    del encoder_mask

    ### YOUR CODE HERE !!!!!

    # Initialize decoder hidden state with the initial hidden state.
    decoder_hidden = initial_hidden

    # embedded_decoder_input: max_decoder_sequence_length x batch_size x word_vector_dim
    embedded_decoder_input = self.embedder(decoder_input)

    # lstm_out: max_decoder_sequence_length x batch_size x hidden_dim
    lstm_out, decoder_hidden = self.lstm2(embedded_decoder_input, decoder_hidden)

    # Apply dropout
    lstm_out = self.dropout2(lstm_out)

    # Compute logits for next-word prediction
    logits = self.output_layer2(lstm_out)

    # Apply log softmax to get log probabilities
    log_probs = self.log_softmax_layer(logits)

    return log_probs, decoder_hidden, None



    ### END YOUR CODE HERE !!!!!

  def compute_loss(self, source, target):
    """Run the model on the source and compute the loss on the target.

    Args:
      source: An integer tensor with shape (max_source_sequence_length,
        batch_size) containing subword indices for the source sentences.
      target: An integer tensor with shape (max_target_sequence_length,
        batch_size) containing subword indices for the target sentences.

    Returns:
      A scalar float tensor representing cross-entropy loss on the current batch.
    """

    # Note that for a target sequence like <s> A B C </s>, you would
    # want to run the decoder on the prefix <s> A B C and have it predict the
    # suffix A B C </s>.

    _, batch_size = source.size()
    enc_output, encoder_mask, curr_state = self.encode(source)

    lengths = torch.sum(target != pad_id, axis=0).cpu()-1
    target_prefix = torch.clone(target).cpu()
    target_prefix[lengths,torch.arange(target_prefix.size(1))] = pad_id
    decoder_input = target_prefix[:-1,:].to(device)

    log_probs, _, _ = self.decode(decoder_input, curr_state, enc_output, encoder_mask)

    criterion = nn.NLLLoss(ignore_index=pad_id)
    target = target[1:,:]
    loss = criterion(log_probs.view(-1, vocab.GetPieceSize()), target.view(-1))

    return loss

# %% [markdown]
# We define the following functions for training.  This code will run as provided.

# %%
def train(model, num_epochs, batch_size, model_file):
  """Train the model and save its best checkpoint.

  Model performance across epochs is evaluated using token-level accuracy on the
  validation set. The best checkpoint obtained during training will be stored on
  disk and loaded back into the model at the end of training.
  """
  optimizer = torch.optim.Adam(model.parameters())
  best_accuracy = 0.0
  for epoch in tqdm.notebook.trange(num_epochs, desc="training", unit="epoch"):
    with tqdm.notebook.tqdm(
        make_batch_iterator(training_data, batch_size, shuffle=True),
        desc="epoch {}".format(epoch + 1),
        unit="batch",
        total=math.ceil(len(training_data) / batch_size)) as batch_iterator:
      model.train()
      total_loss = 0.0
      for i, (source, target) in enumerate(batch_iterator, start=1):
        source, target = source.to(device),target.to(device)
        optimizer.zero_grad()
        loss = model.compute_loss(source, target)
        total_loss += loss.item()
        loss.backward()
        optimizer.step()
        batch_iterator.set_postfix(mean_loss=total_loss / i)
      validation_perplexity, validation_accuracy = evaluate_next_token(
          model, validation_data)
      batch_iterator.set_postfix(
          mean_loss=total_loss / i,
          validation_perplexity=validation_perplexity,
          validation_token_accuracy=validation_accuracy)
      if validation_accuracy > best_accuracy:
        print(
            "Obtained a new best validation accuracy of {:.2f}, saving model "
            "checkpoint to {}...".format(validation_accuracy, model_file))
        torch.save(model.state_dict(), model_file)
        best_accuracy = validation_accuracy
  print("Reloading best model checkpoint from {}...".format(model_file))
  model.load_state_dict(torch.load(model_file))

def evaluate_next_token(model, dataset, batch_size=64):
  """Compute token-level perplexity and accuracy metrics.

  Note that the perplexity here is over subwords, not words.

  This function is used for validation set evaluation at the end of each epoch
  and should not be modified.
  """
  model.eval()
  total_cross_entropy = 0.0
  total_predictions = 0
  correct_predictions = 0
  with torch.no_grad():
    for source, target in make_batch_iterator(dataset, batch_size):
      encoder_output, encoder_mask, encoder_hidden = model.encode(source)
      decoder_input, decoder_target = target[:-1], target[1:]
      logits, decoder_hidden, attention_weights = model.decode(
          decoder_input, encoder_hidden, encoder_output, encoder_mask)
      total_cross_entropy += F.cross_entropy(
          logits.permute(1, 2, 0), decoder_target.permute(1, 0),
          ignore_index=pad_id, reduction="sum").item()
      total_predictions += (decoder_target != pad_id).sum().item()
      correct_predictions += (
          (decoder_target != pad_id) &
          (decoder_target == logits.argmax(2))).sum().item()
  perplexity = math.exp(total_cross_entropy / total_predictions)
  accuracy = 100 * correct_predictions / total_predictions
  return perplexity, accuracy

# %% [markdown]
# We can now train the baseline model.
#
# Since we haven't yet defined a decoding method to output an entire string, we will measure performance for now by computing perplexity and the accuracy of predicting the next token given a gold prefix of the output. A correct implementation should get a validation token accuracy above 55%. The training code will automatically save the model with the highest validation accuracy and reload that checkpoint's parameters at the end of training.

# %%
# We tune it to be fairly optimal, so idealy you don't have to change the parameters below.
# But you are welcome to adjust these parameters.

num_epochs = 10
batch_size = 16
hidden_dim = 256
word_vector_dim = 256
num_layers = 2
dropout = 0.3

baseline_model = Seq2seqBaseline(hidden_dim,word_vector_dim,dropout,num_layers).to(device)
train(baseline_model, num_epochs, batch_size, "baseline_model.pt")
# Out:
# training:   0%|          | 0/10 [00:00<?, ?epoch/s]
# epoch 1:   0%|          | 0/1813 [00:00<?, ?batch/s]
# Obtained a new best validation accuracy of 43.88, saving model checkpoint to baseline_model.pt...
# epoch 2:   0%|          | 0/1813 [00:00<?, ?batch/s]
# Obtained a new best validation accuracy of 48.53, saving model checkpoint to baseline_model.pt...
# epoch 3:   0%|          | 0/1813 [00:00<?, ?batch/s]
# Obtained a new best validation accuracy of 51.39, saving model checkpoint to baseline_model.pt...
# epoch 4:   0%|          | 0/1813 [00:00<?, ?batch/s]
# Obtained a new best validation accuracy of 53.12, saving model checkpoint to baseline_model.pt...
# epoch 5:   0%|          | 0/1813 [00:00<?, ?batch/s]
# Obtained a new best validation accuracy of 54.52, saving model checkpoint to baseline_model.pt...
# epoch 6:   0%|          | 0/1813 [00:00<?, ?batch/s]
# Obtained a new best validation accuracy of 55.39, saving model checkpoint to baseline_model.pt...
# epoch 7:   0%|          | 0/1813 [00:00<?, ?batch/s]
# Obtained a new best validation accuracy of 55.81, saving model checkpoint to baseline_model.pt...
# epoch 8:   0%|          | 0/1813 [00:00<?, ?batch/s]
# epoch 9:   0%|          | 0/1813 [00:00<?, ?batch/s]
# epoch 10:   0%|          | 0/1813 [00:00<?, ?batch/s]
# Obtained a new best validation accuracy of 55.91, saving model checkpoint to baseline_model.pt...
# Reloading best model checkpoint from baseline_model.pt...

# %% [markdown]
# For evaluation, we also need to be able to generate entire strings from the model. We gave a greedy decoding algorithm here. Later on, we'll implement beam search.
#
# A correct implementation of baseline model with greedy decoding should get above 19 BLEU on the validation set.

# %%
def predict_greedy(model, sentences, max_length=100):
  """Make predictions for the given inputs using greedy inference.

  Args:
    model: A sequence-to-sequence model.
    sentences: A list of input sentences, represented as strings.
    max_length: The maximum length at which to truncate outputs in order to
      avoid non-terminating inference.

  Returns:
    A list of predicted translations, represented as strings.
  """

  model.eval()
  batch_size = len(sentences)
  indices = make_batch(sentences)
  pred_translations = torch.zeros(max_length,batch_size, dtype=torch.long) # max_seq_length x batch_size

  enc_output, encoder_mask, curr_state = model.encode(indices)
  input = torch.LongTensor([bos_id] * batch_size).view(1, -1).to(device)
  finished_mask = torch.zeros(batch_size, dtype=torch.bool).to(device) # mask ones that have finished because some may finish ealier than the other in the same batch
  for i in range(0, max_length):
      log_probs, hidden, _ = model.decode(input, curr_state, enc_output, encoder_mask)

      # Prevent finished sequences from producing non-padding tokens.
      log_probs[:, finished_mask, pad_id] = 1e9

      # Get the most likely next token and its index.
      _, next_tokens = log_probs.squeeze(0).max(dim=1)
      pred_translations[i] = next_tokens

      # Update the input for the next decoding step.
      input = next_tokens.unsqueeze(0)

      # Update the state and finished masks.
      curr_state = hidden

      finished_mask = finished_mask | next_tokens.eq(eos_id)
      if finished_mask.all():
          break

  pred_translation_str = []
  for i in range(batch_size):
      string = vocab.DecodeIds(pred_translations[:,i].detach().cpu().numpy().astype(int).tolist())
      pred_translation_str.append(string)
  return pred_translation_str


def evaluate(model, dataset, batch_size=64, method="greedy"):
  assert method in {"greedy", "beam"}
  source_sentences = [example[0] for example in dataset]
  target_sentences = [example[1] for example in dataset]
  model.eval()
  predictions = []
  with torch.no_grad():
    for start_index in range(0, len(source_sentences), batch_size):
      if method == "greedy":
        prediction_batch = predict_greedy(
            model, source_sentences[start_index:start_index + batch_size])
      else:
        prediction_batch = predict_beam(
            model, source_sentences[start_index:start_index + batch_size])
        prediction_batch = [candidates[0] for candidates in prediction_batch]
      predictions.extend(prediction_batch)
  return sacrebleu.corpus_bleu(predictions, [target_sentences]).score

print("Baseline model validation BLEU using greedy search:",
      evaluate(baseline_model, validation_data))

### Generate the predictions for the baseline model using greedy decoding on the test_data.
generate_predictions_file_for_submission("seq2seq_predictions_baseline.json", baseline_model, test_data, "greedy")
# Out:
# Baseline model validation BLEU using greedy search: 20.72821751958139
# Finished writing predictions to seq2seq_predictions_baseline.json.

# %%
def show_predictions(model, num_examples=4, num_beam=5,include_beam=False):
  for example in validation_data[:num_examples]:
    print("Input:")
    print(" ", example[0])
    print("Target:")
    print(" ", example[1])
    print("Greedy prediction:")
    print(" ", predict_greedy(model, [example[0]])[0])
    if include_beam:
      print(f"Beam predictions (showing top {num_beam}):")
      for candidate in predict_beam(model, [example[0]])[0][:num_beam]:
        print(" ", candidate)
    print()

print("Baseline model sample predictions:")
print()
show_predictions(baseline_model)
# Out:
# Baseline model sample predictions:
#
# Input:
#   Eine Gruppe von Männern lädt Baumwolle auf einen Lastwagen
# Target:
#   A group of men are loading cotton onto a truck
# Greedy prediction:
#   A group of men are working on a steel time.
#
# Input:
#   Ein Mann schläft in einem grünen Raum auf einem Sofa.
# Target:
#   A man sleeping in a green room on a couch.
# Greedy prediction:
#   A man is sleeping on a green couch with a beard.
#
# Input:
#   Ein Junge mit Kopfhörern sitzt auf den Schultern einer Frau.
# Target:
#   A boy wearing headphones sits on a woman's shoulders.
# Greedy prediction:
#   A boy in pigtails sits on the phone with a woman.
#
# Input:
#   Zwei Männer bauen eine blaue Eisfischerhütte auf einem zugefrorenen See auf
# Target:
#   Two men setting up a blue ice fishing hut on an iced over lake
# Greedy prediction:
#   Two men are performing a blue plastic folding against a blue tent.

# %% [markdown]
# ## Attention
# We'll now improve our seq2seq parsing model by adding [Luong et al. (2015)](https://arxiv.org/pdf/1508.04025.pdf) style attention. In particular, (largely following the notation in the paper) let $\bar{\mathbf{h}}_1, \ldots, \bar{\mathbf{h}}_S$ be the sequence of *encoder* RNN states which are obtained from running the encoder RNN over $S$ source tokens (i.e., the English words in the question in our case). Also let $\mathbf{h}_t$ be the *decoder* RNN state after it consumes the $t$th target token (i.e., the $t$th token in the logical form). Then $\boldsymbol{\alpha}_t$, the attention vector at time $t$, has $S$ elements defined as follows:
# $$
# \alpha_{t,s} = \mathrm{softmax} ([\bar{\mathbf{h}}_{1}^{\top}; \ldots; \bar{\mathbf{h}}_{S}^{\top}] \mathbf{W}_a^{\top} \mathbf{h}_t)_s = \frac{\exp(\mathbf{h}_t^{\top} \mathbf{W}_a \bar{\mathbf{h}}_s)}{\sum_{s'=1}^S\exp(\mathbf{h}_t^{\top} \mathbf{W}_a \bar{\mathbf{h}}_{s'})},
# $$
# where vectors are assumed to be column-vectors and $;$ represents vertical stacking. Note $\mathbf{W}_a \in \mathbb{R}^{d_{dec} \times d_{enc}}$ is a learnable parameter matrix.
#
# Given $\boldsymbol{\alpha}_t$, we can then compute a "context vector" $\mathbf{c}_t$ that is a weighted average of the encoder states:
# $$
# \mathbf{c}_t = [\bar{\mathbf{h}}_{1}, \ldots, \bar{\mathbf{h}}_{S}] \boldsymbol{\alpha}_t
# $$
# where $,$ represents horizontal stacking.
#
# Finally, we concatenate $\mathbf{c}_t$ and $\mathbf{h}_t$ to arrive at a modified decoder state at time $t$ defined as follows:
# $$
# \tilde{\mathbf{h}}_t = \tanh(\mathbf{W}_c [\mathbf{c}_t; \mathbf{h}_t]),
# $$
# where $\mathbf{W}_c \in \mathbb{R}^{d_{dec} + d_{enc} \times d_{dec} + d_{enc}} $ is some learned projection. We can then obtain our logits for each word type as usual with $\mathbf{V} \tilde{\mathbf{h}}_t + \mathbf{b}$.
#
#
# ### **Implementation Task \# 2**
# Complete the `decode()` function of the `Seq2seqAttention` module below so that it implements the attention scheme described above. The function should return log probabilities and the final decoder state and cell just as the `decode()` function of the `Seq2seqBaseline` module above does.
#
# **Hint:** The most efficient implementations will make use of [`torch.bmm`](https://pytorch.org/docs/stable/generated/torch.bmm.html) in computing attention.

# %%
class Seq2seqAttention(Seq2seqBaseline):
  # Note that this class inherents from Seq2seqBaseline, so all the parameters in Seq2seqBaseline are initialized when this class is
  # initialized.
  def __init__(self, hidden_dim, enc_output_size, word_vector_dim, dropout,num_layers):
    super().__init__(hidden_dim, word_vector_dim, dropout,num_layers)

    # Initialize any additional parameters needed for this model that are not
    # already included in the baseline model.

    ### YOUR CODE HERE !!!!!
    self.d_enc=2*hidden_dim
    self.d_dec=hidden_dim
    self.W_a = nn.Linear(self.d_enc,self.d_dec, bias=False)
    self.W_c = nn.Linear(self.d_dec + self.d_enc, self.d_dec + self.d_enc,bias=False)
    self.output_layer2 = nn.Linear((self.d_dec+self.d_enc), vocab.GetPieceSize())
    self.log_softmax_layer = nn.LogSoftmax(dim=2)

    ### END YOUR CODE HERE !!!!!

  def decode(self, decoder_input, initial_hidden, encoder_output, encoder_mask):
    """Run the decoder LSTM starting from an initial hidden state.

    Args:
      decoder_input: An integer tensor with shape (max_decoder_sequence_length,
        batch_size) containing the subword indices for the decoder input. During
        evaluation, where decoding proceeds one step at a time, the initial
        dimension should be 1.
      initial_hidden: A pair of tensors (h_0, c_0) representing the initial
        state of the decoder, each with shape (num_layers, batch_size,
        hidden_size).
      encoder_output: The output of the encoder with shape
        (max_source_sequence_length, batch_size, 2 * hidden_size).
      encoder_mask: The output mask from the encoder with shape
        (max_source_sequence_length, batch_size). Encoder outputs at positions
        with a True value correspond to padding tokens and should be ignored.

    Returns:
      A tuple with three elements:
        logits: A tensor with shape (max_decoder_sequence_length, batch_size,
          vocab_size) containing scores for the next-word
          predictions at each position.
        decoder_hidden: A pair of tensors (h_n, c_n) with the same shape as
          initial_hidden representing the updated decoder state after processing
          the decoder input.
        attention_weights: A tensor with shape (max_decoder_sequence_length,
          batch_size, max_source_sequence_length) representing the normalized
          attention weights. This should sum to 1 along the last dimension.
    """

    # Implementation tip: use a large negative number like -1e9 instead of
    # float("-inf") when masking logits to avoid numerical issues.

    # Implementation tip: the function torch.bmm may be useful here.
    # See https://pytorch.org/docs/stable/generated/torch.bmm.html

    ### YOUR CODE HERE !!!!!

    max_dec_seqlen, batch_size = decoder_input.shape

    # get the number of vocab tokens we have so we can return a logit score.
    vocab_size=vocab.GetPieceSize()

    # Initialize decoder hidden state with the initial hidden state.
    decoder_hidden = initial_hidden

    # embedded_decoder_input: max_decoder_sequence_length x batch_size x word_vector_dim
    embedded_decoder_input = self.embedder(decoder_input)

    # lstm_out: max_decoder_sequence_length x batch_size x hidden_dim
    lstm_out, decoder_hidden = self.lstm2(embedded_decoder_input, decoder_hidden)


    #################################################################################
    ### DEAL WITH DIMENSIONS DUE TO BATCHING IN BEAM SEARCH #########################
    #################################################################################

    # linear_out: max_decoder_sequence_length x batch_size x hidden_dim
    if encoder_output.shape[1]!=lstm_out.shape[1]:
      encoder_output=encoder_output.tile(1,lstm_out.shape[1],1)
      encoder_mask=encoder_mask.tile(1,lstm_out.shape[1])
    linear_out=self.W_a(encoder_output)


    #################################################################################
    ##########################     COMPUTE ATTENTION    #############################
    #################################################################################


    # h_w_h_bar: batch_size x max_encoder_sequence_length  x max_decoder_sequence_length
    # print(linear_out.permute(1,0,2).shape)
    # print(lstm_out.permute(1,2,0).shape)
    h_W_h_bar=torch.bmm(linear_out.permute(1,0,2), lstm_out.permute(1,2,0))

    # h_w_h_bar: batch_size x max_encoder_sequence_length  x max_decoder_sequence_length
    h_W_h_bar_masked=h_W_h_bar+torch.permute(encoder_mask,(1,0)).unsqueeze(2)*(-1e9)


    # print("Max_dec:", max_dec_seqlen)
    alpha=torch.softmax(h_W_h_bar_masked,dim=1)
    # print(alpha.shape)


    ###################################################
    ###########       FIND CONTEXT         ############
    ###################################################


    # encoder_output: max_source_sequence_length x batch_size x 2 * hidden_size
    # alpha: max_decoder_sequence_length x batch_size x max_encoder_sequence_length

    # context: batch_size x max_encoder_sequence_length  x (hidden_dec + hidden_enc)
    context = torch.bmm(torch.permute(encoder_output,(1,2,0)), alpha)


    # Concatenate context and lstm_out along the last dimension
    # stacked: batch_size x max_encoder_sequence_length x (hidden_dec + hidden_enc)
    stacked = torch.cat((context, torch.permute(lstm_out,(1, 2, 0))), dim=1)

    h_tilde = torch.tanh(self.W_c(torch.permute(stacked,(2,0,1))))
    # print(h_tilde.shape)


    ####################################################

    # Apply dropout
    h_tilde_dropout = self.dropout2(h_tilde)
    # print(h_tilde_dropout.shape)

    # Compute logits for next-word prediction
    logits = self.output_layer2(h_tilde_dropout)


    # Apply log softmax to get log probabilities
    log_probs = self.log_softmax_layer(logits)

    return log_probs.contiguous(), decoder_hidden, alpha


    ### END YOUR CODE HERE !!!!!

# %% [markdown]
# As before, we can train an attention model using the provided training code.
#
# A correct implementation should get a validation token accuracy above 67 and a validation BLEU above 36 with greedy search.

# %%
# You are welcome to adjust these parameters based on your model implementation.
num_epochs = 10
batch_size = 16
hidden_dim = 256 ### Modify as hyperparameter [originally 256] Values : 128, 256, 512
enc_output_size = hidden_dim * 2
word_vector_dim = 256
num_layers = 2
dropout = 0.2 #### Modify dropout [originally 0.3] Values : 0.2, 0.3, 0.5

attention_model = Seq2seqAttention(hidden_dim,enc_output_size, word_vector_dim,dropout,num_layers).to(device)
train(attention_model, num_epochs, batch_size, "attention_model.pt")
print("Attention model validation BLEU using greedy search:",
      evaluate(attention_model, validation_data))
# Generate the predictions for the attention model using greedy decoding on the test_data.
# Corret implementation of the baseline model and attention model should get you full credits here.
generate_predictions_file_for_submission("seq2seq_predictions_attention.json", attention_model, test_data, "greedy")
# Out:
# training:   0%|          | 0/10 [00:00<?, ?epoch/s]
# epoch 1:   0%|          | 0/1813 [00:00<?, ?batch/s]
# Obtained a new best validation accuracy of 59.81, saving model checkpoint to attention_model.pt...
# epoch 2:   0%|          | 0/1813 [00:00<?, ?batch/s]
# Obtained a new best validation accuracy of 64.24, saving model checkpoint to attention_model.pt...
# epoch 3:   0%|          | 0/1813 [00:00<?, ?batch/s]
# Obtained a new best validation accuracy of 66.12, saving model checkpoint to attention_model.pt...
# epoch 4:   0%|          | 0/1813 [00:00<?, ?batch/s]
# Obtained a new best validation accuracy of 66.94, saving model checkpoint to attention_model.pt...
# epoch 5:   0%|          | 0/1813 [00:00<?, ?batch/s]
# Obtained a new best validation accuracy of 67.42, saving model checkpoint to attention_model.pt...
# epoch 6:   0%|          | 0/1813 [00:00<?, ?batch/s]
# epoch 7:   0%|          | 0/1813 [00:00<?, ?batch/s]
# epoch 8:   0%|          | 0/1813 [00:00<?, ?batch/s]
# epoch 9:   0%|          | 0/1813 [00:00<?, ?batch/s]
# epoch 10:   0%|          | 0/1813 [00:00<?, ?batch/s]
# Reloading best model checkpoint from attention_model.pt...
# Attention model validation BLEU using greedy search: 37.67828372164295
# Finished writing predictions to seq2seq_predictions_attention.json.

# %% [markdown]
# ## Beam Search
#
# We will now try to improve our model's predictions by decoding with beam search, rather than greedily. Beam search maintains a `beam_size`-length list of hypotheses at each step of decoding. A hypothesis is just a prefix of a full prediction, and is represented in the code below by a `Hyp` object.
#
# ### What beam search does, in (mostly) words
# Beam search starts with a hypothesis consisting just of the BOS token, and then proceeds for `output_max_len` steps. At each step $t$, beam search considers adding every possible next-word to the hypotheses/prefixes from step $t-1$ (for a total of `beam_size`*V hypotheses). It then takes the highest scoring `beam_size` of these candidate hypotheses to be the hypotheses at step $t$. The score of a hypothesis of length $t$ is:
# $$
# \mathrm{score}(w_1, \ldots, w_t) = \sum_{i=1}^t \log p(w_i|w_1, \ldots, w_{i-1}, x)
# $$
# where $x$ is the source question. The log probabilities above are just the standard ones output by your RNN decoder.
#
# A hypothesis is finished when it ends with an EOS token.
#
# With beam search, you should get an improvement of at least 1 BLEU over greedy search, and should reach above 21 BLEU without attention and above 38 BLEU with attention.
#
# **Tips:**
#
# 1) A good general strategy when doing complex code like this is to carefully annotate each line with a comment saying what each dimension represents.
#
# 2) You should only need one call to topk per step. You do not need to have a topk just over vocabulary first, you can directly go from vocab_size*beam_size to beam_size items.
#
# 3) Be sure you are correctly keeping track of which beam item a candidate is selected from and updating the beam states, such as LSTM hidden state, accordingly. A single state from the previous time step may need to be used for multiple new beam items or not at all. This includes all state associated with a beam, including all past tokens output by the beam and any extra tensors such as ones remembering when a beam is finished.
#
# 4) Once an EOS token has been generated, save the hypothesis and take it out of the beam for the next timestep.
#
# ### **Implementation Task \# 3**
# Fill in the missing code in the `predict_beam` function below. You are not implementing batched beam_search so you only need to consider one sentence at a time.

# %%
class Hyp:
  """
  A helper class representing a hypothesis (i.e., the prefix of a prediction) on the beam,
  using a linked list.
  """
  def __init__(self, token_id:int, parent, score:float):
    """
    args:
      token: a word (as a string) representing the most recent word added to this hypothesis
      parent: the Hyp object representing the prefix to which we've added this token
      score: the score of this hypothesis
    """
    self.token_id = token_id
    self.parent = parent
    self.score = score


  def trace(self):
    """
    Traces backward through the linked-list to recover the whole hypothesis.
    returns:
      A list of word tokens representing the entire hypothesis.
    """
    pred = []
    temp = self
    while temp.token_id is not None:
      pred.append(temp.token_id)
      temp = temp.parent
    return pred[::-1]

def predict_beam(model, sentences, k=5, max_length=100):
    """Output the beam search result for the given sentences.

    Args:
      model: The model that will be used to generate the beams.
      sentences: A list of sentences (str) that the model will encode and do
        beam search over. To keep things simple, this will just be a list of
        length 1. So it will be a list of a single string.
      k: Beam size.
      max_length: Maximum timesteps you will generate. If it exceeds this
        timestep stop no matter what.

    Returns:
      A list of decoded generations (strings) sorted by their scores in descending order.
      The format should be [[beam decoded sentence1, beam decoded sentence2,...]]
      Note the extra list outside. We do this to keep the format compatible when
      batch_size > 1 in case you want to implement batched beam search (It is not required).
    """
    model.eval()
    all_decoded_generations = []
    V = vocab.GetPieceSize()
    indices = make_batch(sentences)
    enc_output, encoder_mask, curr_state = model.encode(indices) # seq_len x batch_size x 2d, seq_len x batch_size, (2 x batch_size x d, 2 x batch_size x d) batch_size would be 1 here.
    # always start with SOS_SYMBOL
    input = torch.LongTensor([bos_id]).view(1, 1).to(device)
    hyps = [Hyp(None, None, 0)] # holds current hypotheses; initialized with a dummy hypothesis.
    decoded_generations = [] # holds decoded generations (obtained from finished hypotheses)
    beam_logprobs = torch.zeros(1).to(device) # log probabilities of all hypotheses on the beam

    ##### BEGIN YOUR CODE HERE!!!!!!!!
    ## Note: the ideal implementation should process all the hypotheses on the beam in parallel using the batch dimension,
    ## i.e., only make 1 call to model.decode at each time step.
    ## Additionally, it should process all the k X V log probabilities together to get the topk using torch.topk.
    ## There are other ways to do this (e.g., iterating over the beam hypotheses), but these may lead to slightly lower
    ## scores for beam_seqs.json on gradescope since the ties may be broken differently.


    # it should probably start with:
    for t in range(0, max_length):
      #decoder_input, initial_hidden, encoder_output, encoder_mask
      """"
      decoder_input: An integer tensor with shape (max_decoder_sequence_length,
        batch_size) containing the subword indices for the decoder input. During
        evaluation, where decoding proceeds one step at a time, the initial
        dimension should be 1.
      initial_hidden: A pair of tensors (h_0, c_0) representing the initial
        state of the decoder, each with shape (num_layers, batch_size,
        hidden_size).
      encoder_output: The output of the encoder with shape
        (max_source_sequence_length, batch_size, 2 * hidden_size).
      encoder_mask: The output mask from the encoder with shape
        (max_source_sequence_length, batch_size). Encoder outputs at positions
        with a True value correspond to padding tokens and should be ignored.
      """
      #encoder_output:max_source_sequence_length(1) x batch_size(5) x 2 * hidden_size(512)
      #encoder_mask:max_source_sequence_length(1) x batch_size(5)
      #model_log_probs: max_decoder_sequence_length(1) x batch_size(initially 1 and then 5) x vocab_size [scores for next word prediction at each stage] V
      #curr_state: pair of tensors (h_n, c_n) num_layers(2) x batch_size(1) x hidden_size(256)
      model_log_probs, curr_state, _ = model.decode(input, curr_state,enc_output, encoder_mask)

      # batch_size(initially 1 and then 5) x vocab_size + (batch_size batch_size(initially 1 and then 5) x vocab_size) -> flatten to get 5*V tensor
      # print("SHAPE OF MODEL LOG PROBS",model_log_probs.shape)
      # print("SHAPE OF BEAM",beam_logprobs.shape)

      log_probs=model_log_probs.squeeze()+beam_logprobs

      # beam_logprobs: batch_size(1, then 5) , beam_indices: batch_size(1, then 5)
      beam_logprobs,beam_indices=torch.topk(log_probs.flatten(),k, largest=True, sorted=True)

      # create a new hyps list
      new_hyps=[]
      next_token_id_list=[]
      next_beam_score_list=[]
      h_n=[]
      c_n=[]

      # iterate over every element that is in top k.
      for i,index in enumerate(beam_indices):
            # print(index)
            # Append the new object to the hyps list we create, where the parent is determined
            # by the hyps[index//V] which takes the index of word in the flattened set, finds the corresponding mapping bucket.
            # and the score is calculated as beam_logprobs[i] and the token id is given by index%V.
            if ((index%V)==2): # if we reach an EOS token but its not the highest score, carry on
              final_obj=Hyp((index%V).item(),hyps[(index//V).item()],beam_logprobs[i])
              final_trace=final_obj.trace()
              # print("FINAL TRACE",final_trace)
              # print( "We reach an end of sentence token for the hypothesis with the greatest score" )
              # print(final_trace)
              prediction=vocab.DecodeIds(final_trace)
              print(prediction)
              decoded_generations.append(prediction)
              # print("BEAM LOGPROBS SHAPE",beam_logprobs.shape)
              if len(decoded_generations)==k:
                all_decoded_generations.append(decoded_generations)
                return all_decoded_generations
              # idx_to_rmv=i
            else:
              token_id=(index%V).item()
              parent=(index//V).item() #parent index
              score=beam_logprobs[i]
              new_hyps.append(Hyp(token_id,hyps[parent],score))
              h_n.append(torch.index_select(curr_state[0], 1,torch.tensor(parent).to(device)).squeeze(1))
              c_n.append(torch.index_select(curr_state[1], 1, torch.tensor(parent).to(device)).squeeze(1))
              next_token_id_list.append(token_id) # picks the next beam
              next_beam_score_list.append(score)
      # if (idx_to_rmv is not None):
      #   beam_logprobs=torch.cat((beam_logprobs[:idx_to_rmv],beam_logprobs[idx_to_rmv+1:]))

      beam_logprobs=torch.tensor(next_beam_score_list).to(device)

      # ################# FIX SIZE OF ENCODER OUTPUT AND MASK ################
      # enc_output=enc_output.tile(1,len(next_token_id_list),1)
      # encoder_mask=encoder_mask.tile(1,len(next_token_id_list))
      # #####################################################################

      # print(len(h_n),h_n[0].shape)
      #curr_state=(h_n.tile(1,len(next_token_id_list),1),c_n.tile(1,len(next_token_id_list),1))
      h_index=torch.stack(h_n, dim=1)
      c_index=torch.stack(c_n, dim=1)

      # print(h_index.shape)
      curr_state=(h_index,c_index)

      #update the hyps list
      hyps=new_hyps

      # beam_logprobs: batch_size (5) * 1 (added by unsqueezing)
      beam_logprobs=beam_logprobs.unsqueeze(1)

      # beam_indices: batch_size (5) * 1 (added by unsqueezing)
      beam_indices=beam_indices.unsqueeze(1)

      # update input vector to max_decoder_sequence_length (1) x batch_size (5) with k tokens along batch_size

      input=torch.LongTensor(next_token_id_list).to(device).unsqueeze(0)

    print("We ran out of iterations....")

    # if we run out of iterations we have to manually loop through Hyps and append each word
    for obj in hyps:
      final_obj=obj
      final_trace=final_obj.trace()
      prediction=vocab.DecodeIds(final_trace)
      print(prediction)
      decoded_generations.append(prediction)
      if len(decoded_generations)==k:
          all_decoded_generations.append(decoded_generations)
          return all_decoded_generations


    return decoded_generations



    ##### END YOUR CODE HERE!!!!!!!!

print("Baseline model validation BLEU using beam search:",
      evaluate(baseline_model, validation_data, batch_size=1, method="beam"))
print()
print("Baseline model sample predictions:")
print()
show_predictions(baseline_model, include_beam=True)

# %%
print("Attention model validation BLEU using beam search:",
      evaluate(attention_model, validation_data, batch_size=1, method="beam"))
print()
print("Attention model sample predictions:")
print()
show_predictions(attention_model, include_beam=True)

# %% [markdown]
# Run the cells to generate the beam_seqs.json file required for submission to check correctness of your beam_search.

# %%
# !gdown 1zKM1vgKkRye1COYh4IlH_m0xDCq7chFF
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1zKM1vgKkRye1COYh4IlH_m0xDCq7chFF
# To: /content/special_model_beam_search.pt
# 100% 7.89M/7.89M [00:00<00:00, 203MB/s]

# %%
device = torch.device("cpu") # we load the special model to cpu to compute the beams. Beam search under CPU and GPU may have small variations due to how Pytorch implemented them.
hidden_dim = 100
word_vector_dim = 100
num_layers = 1
dropout = 0.3

special_model = Seq2seqBaseline(hidden_dim,word_vector_dim,dropout,num_layers).to(device)
sd = torch.load("special_model_beam_search.pt")
special_model.load_state_dict(sd)

V = vocab.GetPieceSize()
nsrcs, srcsize = 11, 6
special_preds = {}
for beam_size in [1, 5, 10, 15]:
  torch.manual_seed(beam_size)
  srcs = [(vocab.DecodeIds(torch.LongTensor(srcsize).random_(0, V).numpy().tolist()),
           'filler target sentence filler target sentence filler target sentence') for _ in range(nsrcs)]
  predictions = []
  source_sentences = [x[0] for x in srcs]
  for start_index in range(0, len(source_sentences), 1):
        prediction_batch = predict_beam(
            special_model, source_sentences[start_index:start_index + 1], k=beam_size,max_length=50)
        predictions.extend(prediction_batch)
  special_preds[beam_size] = predictions

with open("beam_seqs.json", "w") as f:
    json.dump(special_preds, f)

# %%
device = torch.device("cuda")

# %% [markdown]
# If you implemented beam search correctly, you can save the results of beam search for the attention model by uncommenting the code below. It will have higher BLEU score, but the greedy decoding should give you full 20%.

# %%
generate_predictions_file_for_submission("seq2seq_predictions_attention.json", attention_model, test_data, "beam", batch_size=1)
# Out:
# Streaming output truncated to the last 5000 lines.
# A table full of fish open, an open market.
# We reach an end of sentence token for the hypothesis with the greatest score
# A table full of fish open, an open market market.
# We reach an end of sentence token for the hypothesis with the greatest score
# A table full of fish open, an open market, market.
# We reach an end of sentence token for the hypothesis with the greatest score
# A table full of fish open, an open market, an open market.
# We reach an end of sentence token for the hypothesis with the greatest score
# A table full of fish open, an open market, open for sale.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two people sit against a wall while making faces.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two people sitting against a wall while making faces.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two people are sitting against a wall while making faces.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two people sitting against a wall while making faces and making faces.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two people are sitting against a wall while making faces and making faces.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two guys with painted prints are smiling.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two guys with painted painted painted are smiling.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two guys with braided chests are smiling.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two guys with painted painted are talking to each other
# We reach an end of sentence token for the hypothesis with the greatest score
# Two guys with painted painted are talking to each other.
# We reach an end of sentence token for the hypothesis with the greatest score
# A child is laying on a beige carpet.
# We reach an end of sentence token for the hypothesis with the greatest score
# A child is laying on a beige carpet and laughing
# We reach an end of sentence token for the hypothesis with the greatest score
# A child is laying on a beige carpet and laughing.
# We reach an end of sentence token for the hypothesis with the greatest score
# A child is laying on a beige carpet while laughing.
# We reach an end of sentence token for the hypothesis with the greatest score
# A child is laying on a beige carpet and laughs.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man and a woman are sitting, dressed in each other and their arms.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man and a woman are sitting, dressed in each other, and they are sitting.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man and a woman are sitting, dressed in each other, and they are smiling.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man and a woman sit, each dressed in each other, and they are sitting.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man and a woman are sitting, dressed in each other, and their arms are sitting.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two women are playing in a children in mud.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two women are playing in a children in the mud
# We reach an end of sentence token for the hypothesis with the greatest score
# Two women are playing in a children in the mud.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two women are playing in a children in the dirt.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two women are playing in a children in their mud
# We reach an end of sentence token for the hypothesis with the greatest score
# A guy in a white shirt walking with a drink.
# We reach an end of sentence token for the hypothesis with the greatest score
# A guy in a white shirt strolls with a drink.
# We reach an end of sentence token for the hypothesis with the greatest score
# A guy in a white shirt strolls by a drink.
# We reach an end of sentence token for the hypothesis with the greatest score
# A guy wearing a white shirt strolls with a drink.
# We reach an end of sentence token for the hypothesis with the greatest score
# A guy in a white shirt strolls with a beverage.
# We reach an end of sentence token for the hypothesis with the greatest score
# A silhouette of two people on a lake that has a colorful sky.
# We reach an end of sentence token for the hypothesis with the greatest score
# The silhouettes of two people on a lake with a colorful sky.
# We reach an end of sentence token for the hypothesis with the greatest score
# The silhouettes of two people on a lake that has a colorful sky.
# We reach an end of sentence token for the hypothesis with the greatest score
# A silhouette of two people on a lake that has a colorful sky on.
# We reach an end of sentence token for the hypothesis with the greatest score
# A silhouette of two people on a lake that has a colorful sky that is meditating.
# We reach an end of sentence token for the hypothesis with the greatest score
# Several mostly dressed people sit at a table.
# We reach an end of sentence token for the hypothesis with the greatest score
# Several mostly dressed people sitting at a table.
# We reach an end of sentence token for the hypothesis with the greatest score
# Several mostly dressed people are sitting at a table.
# We reach an end of sentence token for the hypothesis with the greatest score
# Several dismo dressed people sit at a table.
# We reach an end of sentence token for the hypothesis with the greatest score
# Several people are dressed in front of a table, sitting at a table
# We reach an end of sentence token for the hypothesis with the greatest score
# Two girls, one in blue and the other in pink, one in pink.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two girls in blue, one in blue and the other in pink, race.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two girls, one in blue and the other in pink, the other in pink.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two girls, one in blue and the other in pink, one in pink, race.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two girls, one in blue and the other in pink, the other in pink, race.
# We reach an end of sentence token for the hypothesis with the greatest score
# The four people sit on a pile of stone
# We reach an end of sentence token for the hypothesis with the greatest score
# The four people sit on a pile of stone.
# We reach an end of sentence token for the hypothesis with the greatest score
# The four people are sitting on a pile of stone.
# We reach an end of sentence token for the hypothesis with the greatest score
# The four people sit on a pile of stones.
# We reach an end of sentence token for the hypothesis with the greatest score
# The four people sit on a pile of stone stairs.
# We reach an end of sentence token for the hypothesis with the greatest score
# A group of people doing tricks on motorcycles
# We reach an end of sentence token for the hypothesis with the greatest score
# A group of people doing tricks on motorcycles.
# We reach an end of sentence token for the hypothesis with the greatest score
# A group of girls doing tricks on motorcycles.
# We reach an end of sentence token for the hypothesis with the greatest score
# A group of people are doing tricks on motorcycles.
# We reach an end of sentence token for the hypothesis with the greatest score
# A group of people are doing tricks on the motorcycle
# We reach an end of sentence token for the hypothesis with the greatest score
# Cyclists in racing gear pass a wooded area.
# We reach an end of sentence token for the hypothesis with the greatest score
# Cyclists in racing gear walk through a wooded area.
# We reach an end of sentence token for the hypothesis with the greatest score
# Cyclists in racing gear pass through a wooded area.
# We reach an end of sentence token for the hypothesis with the greatest score
# Cyclists in racing gear are driving through a wooded area
# We reach an end of sentence token for the hypothesis with the greatest score
# Cyclists in racing gear are driving through a wooded area.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man in a green shirt walking on the beach with his garage.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man in a green shirt is walking on the beach with his garage.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man wearing a green shirt is walking on the beach with his garage.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man in a green shirt is walking on the beach with his sneakers.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man in a green shirt is walking on the beach with his crayon.
# We reach an end of sentence token for the hypothesis with the greatest score
# Several men are standing around an anish race.
# We reach an end of sentence token for the hypothesis with the greatest score
# Several men are standing around an ancient race.
# We reach an end of sentence token for the hypothesis with the greatest score
# Several men are standing around an overnage race.
# We reach an end of sentence token for the hypothesis with the greatest score
# Several men are standing around an overnet race.
# We reach an end of sentence token for the hypothesis with the greatest score
# Several men are standing around an overnnet race
# We reach an end of sentence token for the hypothesis with the greatest score
# Two men working under a white race car.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two men work under a white race car.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two men working below a white race car.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two men are working under a white race car.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two men are working below a white race car.
# We reach an end of sentence token for the hypothesis with the greatest score
# Children jump into a pool.
# We reach an end of sentence token for the hypothesis with the greatest score
# Children jump into a pool of pool
# We reach an end of sentence token for the hypothesis with the greatest score
# Children jump into a pool of pool.
# We reach an end of sentence token for the hypothesis with the greatest score
# Children are jumping out of a pool of pool
# We reach an end of sentence token for the hypothesis with the greatest score
# Children are jumping out of a pool of pool.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man stands on the edge of a wall about about to cross.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man stands at the edge of a wall about to fall down.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man stands at the edge of a wall about about to cross.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man is standing on the edge of a wall about about to cross.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man is standing on the edge of a wall about to fall down.
# We reach an end of sentence token for the hypothesis with the greatest score
# A woman in a striped outfit on a bike.
# We reach an end of sentence token for the hypothesis with the greatest score
# A woman in a striped outfit on a bicycle.
# We reach an end of sentence token for the hypothesis with the greatest score
# A woman wearing a striped outfit on a bike.
# We reach an end of sentence token for the hypothesis with the greatest score
# A woman in a striped outfit is on a bike.
# We reach an end of sentence token for the hypothesis with the greatest score
# A woman in a striped outfit is on a bicycle.
# We reach an end of sentence token for the hypothesis with the greatest score
# Girl in black poses for the camera.
# We reach an end of sentence token for the hypothesis with the greatest score
# The girl in black poses for the camera.
# We reach an end of sentence token for the hypothesis with the greatest score
# A girl in black poses for the camera.
# We reach an end of sentence token for the hypothesis with the greatest score
# A girl wearing black poses for the camera.
# We reach an end of sentence token for the hypothesis with the greatest score
# A young girl wearing black poses for the camera
# We reach an end of sentence token for the hypothesis with the greatest score
# A man in shorts stands near the water.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man in shorts stands by the water.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man wearing shorts stands near the water.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man in shorts stands on the water.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man in shorts is standing near the water.
# We reach an end of sentence token for the hypothesis with the greatest score
# Four black men sitting on the steps of a church.
# We reach an end of sentence token for the hypothesis with the greatest score
# Four black men sit on the steps of a church.
# We reach an end of sentence token for the hypothesis with the greatest score
# Four black males sit on the steps of a church.
# We reach an end of sentence token for the hypothesis with the greatest score
# Four black males sitting on the steps of a church.
# We reach an end of sentence token for the hypothesis with the greatest score
# Four black men sitting on the stairs on the stairs.
# We reach an end of sentence token for the hypothesis with the greatest score
# A crane working in the middle of a pile of tank.
# We reach an end of sentence token for the hypothesis with the greatest score
# A crane working in the middle of a pile of rubble.
# We reach an end of sentence token for the hypothesis with the greatest score
# A crane working in the middle of a pile of truck.
# We reach an end of sentence token for the hypothesis with the greatest score
# An crane is working in the middle of a pile of tank.
# We reach an end of sentence token for the hypothesis with the greatest score
# A crane is working in the middle of a pile of tank.
# We reach an end of sentence token for the hypothesis with the greatest score
# A gymnast in red and white floating on an unfinished beam.
# We reach an end of sentence token for the hypothesis with the greatest score
# A gymnast in red and white floating on an unpainting beam.
# We reach an end of sentence token for the hypothesis with the greatest score
# A gymnast in red and white in the spinning beams on a unpoper.
# We reach an end of sentence token for the hypothesis with the greatest score
# A gymnast in red and white is in the spinning beams on a unal beam.
# We reach an end of sentence token for the hypothesis with the greatest score
# A gymnast in red and white is in the spinning beams on a unpoper.
# We reach an end of sentence token for the hypothesis with the greatest score
# An older lady in a green sweatshirt camping.
# We reach an end of sentence token for the hypothesis with the greatest score
# An older lady in a green sweatshirt filling.
# We reach an end of sentence token for the hypothesis with the greatest score
# An elderly lady in a green sweatshirt filling.
# We reach an end of sentence token for the hypothesis with the greatest score
# An older lady in a green sweatshirt filling a vegetable.
# We reach an end of sentence token for the hypothesis with the greatest score
# An elderly lady in a green sweatshirt filling a vegetable
# We reach an end of sentence token for the hypothesis with the greatest score
# Two men are making craft items in a garage.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two men are putting on tools in a garage.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two men are working in a craft with tooly items
# We reach an end of sentence token for the hypothesis with the greatest score
# Two men are working in a craft with tooly items.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two men are putting on tools in a garage with tool items.
# We reach an end of sentence token for the hypothesis with the greatest score
# A teacher wearing white and a young girl in a yellow dress playing with construction blocks.
# We reach an end of sentence token for the hypothesis with the greatest score
# A teacher in white and a young girl in a yellow dress playing with construction blocks.
# We reach an end of sentence token for the hypothesis with the greatest score
# A teacher wearing white and a young girl in a yellow dress play with construction blocks.
# We reach an end of sentence token for the hypothesis with the greatest score
# A teacher dressed in white and a young girl in a yellow dress playing with construction blocks.
# We reach an end of sentence token for the hypothesis with the greatest score
# A teacher dressed in white and a young girl in a yellow dress play with construction blocks.
# We reach an end of sentence token for the hypothesis with the greatest score
# A young child sleeps in his bed with an open book on the chest.
# We reach an end of sentence token for the hypothesis with the greatest score
# A young child sleeps in his bed with an open book on his chest.
# We reach an end of sentence token for the hypothesis with the greatest score
# A young child sleeps in his bed with an open book on its chest.
# We reach an end of sentence token for the hypothesis with the greatest score
# A young child sleeps in his bed with a open book on the chest.
# We reach an end of sentence token for the hypothesis with the greatest score
# A young child is sleeping in his bed with an open book on the chest.
# We reach an end of sentence token for the hypothesis with the greatest score
# A woman eats on a beautiful day on the grass.
# We reach an end of sentence token for the hypothesis with the greatest score
# A woman eats on the grass on a beautiful day.
# We reach an end of sentence token for the hypothesis with the greatest score
# A woman eats on a nice day on a beautiful day.
# We reach an end of sentence token for the hypothesis with the greatest score
# A woman eats on a beautiful day on a beautiful day.
# We reach an end of sentence token for the hypothesis with the greatest score
# A woman is eating on the grass on a beautiful day.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man is walking down a cobblestone street with red roofs.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man is walking down a cobblestone road with red roofs.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man is walking on a cobblestone street next to buildings with red roof.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man is walking on a cobblestone road next to buildings with red roof.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man is walking on a cobblestone street next to buildings with red roofs.
# We reach an end of sentence token for the hypothesis with the greatest score
# A woman wearing a hat is bread.
# We reach an end of sentence token for the hypothesis with the greatest score
# A woman in a hat is playing bread.
# We reach an end of sentence token for the hypothesis with the greatest score
# A woman wearing a hat is playing bread.
# We reach an end of sentence token for the hypothesis with the greatest score
# A woman with a hat is playing bread.
# We reach an end of sentence token for the hypothesis with the greatest score
# A woman in a hat is taking bread.
# We reach an end of sentence token for the hypothesis with the greatest score
# A lone woman uses a large simplme and a fake piano, as she stands in a stop.
# We reach an end of sentence token for the hypothesis with the greatest score
# A lone woman uses a large simplme and a fake piano, as she stands in a slum.
# We reach an end of sentence token for the hypothesis with the greatest score
# A lone woman uses a large simplme and a fake piano, as she stands on a snolim.
# We reach an end of sentence token for the hypothesis with the greatest score
# A lone woman uses a large simplme and a fake piano, as she stands on a snolip.
# We reach an end of sentence token for the hypothesis with the greatest score
# A lone woman uses a large simplme and a fake piano, as she stands on a snolim in a stop.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man in a karate uniform making a performance in front of two judges.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man in a karate uniform is making a performance in front of two judges.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man in a karate uniform is making a show in front of two judges.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man in a karate suit is making a performance in front of two judges.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man in a karate uniform is making a demonstration in front of two judges.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man dressed in formal wear plays the piano on a city street.
# We reach an end of sentence token for the hypothesis with the greatest score
# A balding man is playing a piano on the sidewalk on a city street.
# We reach an end of sentence token for the hypothesis with the greatest score
# A balding man is playing the piano on the sidewalk by a city street.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man dressed in formal wear plays the piano on the sidewalk by a city street
# We reach an end of sentence token for the hypothesis with the greatest score
# A man dressed in formal wear plays a piano on the sidewalk by a city street
# We reach an end of sentence token for the hypothesis with the greatest score
# An older man sits in a chair eating some food.
# We reach an end of sentence token for the hypothesis with the greatest score
# An older man is sitting in a chair eating some food.
# We reach an end of sentence token for the hypothesis with the greatest score
# An older man sits in a chair eating a few snacks.
# We reach an end of sentence token for the hypothesis with the greatest score
# An older man is sitting in a chair eating a few snack.
# We reach an end of sentence token for the hypothesis with the greatest score
# An older man is sitting in a chair eating a few snacks.
# We reach an end of sentence token for the hypothesis with the greatest score
# A woman in a white shirt is working in a cafe at a cafe.
# We reach an end of sentence token for the hypothesis with the greatest score
# A woman in a white shirt is working in a cafe in a cafe.
# We reach an end of sentence token for the hypothesis with the greatest score
# A woman in a white shirt is working in a cafe with their breaths.
# We reach an end of sentence token for the hypothesis with the greatest score
# A woman in a white shirt is working in a cafe with their faces in a cafe.
# We reach an end of sentence token for the hypothesis with the greatest score
# A woman in a white shirt is working in a cafe with their breaths in a cafe.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man in overalls stands on the back of his truck.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man wearing overalls stands on the back of his truck.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man in work clothes on the back of his truck.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man in overalls is standing on the back of his truck.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man in work clothes stands on the back of his truck.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two children watch a small fence.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two children watching horses through a small fence
# We reach an end of sentence token for the hypothesis with the greatest score
# Two children watching horses through a small fence.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two children watch horses through a small fence.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two children are watching horses through a small fence
# We reach an end of sentence token for the hypothesis with the greatest score
# A window with a painted designer
# We reach an end of sentence token for the hypothesis with the greatest score
# A window with a painted designer.
# We reach an end of sentence token for the hypothesis with the greatest score
# A window with a chalked design.
# We reach an end of sentence token for the hypothesis with the greatest score
# A window with a chalky designer
# We reach an end of sentence token for the hypothesis with the greatest score
# A window with a chalked designer.
# We reach an end of sentence token for the hypothesis with the greatest score
# A woman in a bright pink coat stands in front of a woman in a purple coat and makes a funny face in a purple coat
# We reach an end of sentence token for the hypothesis with the greatest score
# A woman in a bright pink coat stands in front of a woman in a purple coat and makes a funny face in a purple coat.
# We reach an end of sentence token for the hypothesis with the greatest score
# A woman in a bright pink coat stands in front of a woman in a purple coat and makes a face-shaped in a purple coat
# We reach an end of sentence token for the hypothesis with the greatest score
# A woman in a bright pink coat stands in front of a woman in a purple coat and makes a face-shaped in a purple coat.
# We reach an end of sentence token for the hypothesis with the greatest score
# A woman in a bright pink coat stands in front of a woman in a purple coat and makes a funny face to a woman in a purple coat
# We reach an end of sentence token for the hypothesis with the greatest score
# A cowboy is on his arm.
# We reach an end of sentence token for the hypothesis with the greatest score
# A cowboy is fixing his arm
# We reach an end of sentence token for the hypothesis with the greatest score
# A cowboy is fixing his arm.
# We reach an end of sentence token for the hypothesis with the greatest score
# A cowboy is admiring his arm.
# We reach an end of sentence token for the hypothesis with the greatest score
# A cowboy is meditating his arm.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man in a yellow shirt and a man in a blue shirt having a conversation
# We reach an end of sentence token for the hypothesis with the greatest score
# A man in a yellow shirt and a man in a blue shirt having a conversation.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man in a yellow shirt and a man in a dark blue shirt having a conversation
# We reach an end of sentence token for the hypothesis with the greatest score
# A man in a yellow shirt and a man in a dark blue shirt having a conversation.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man in a yellow shirt and a man in a blue shirt talking to each other.
# We reach an end of sentence token for the hypothesis with the greatest score
# Three asian children sit on a couch with wall supplies in the background.
# We reach an end of sentence token for the hypothesis with the greatest score
# Three asian children sit on a couch with walls in the background.
# We reach an end of sentence token for the hypothesis with the greatest score
# Three asian children sit on a couch with wall green chairs in the background.
# We reach an end of sentence token for the hypothesis with the greatest score
# Three asian children sit on a couch with wall green supplies in the background.
# We reach an end of sentence token for the hypothesis with the greatest score
# Three asian children are sitting on a couch with wall green chairs in the background
# We reach an end of sentence token for the hypothesis with the greatest score
# A girl in a red shirt leaps to hit a tennis ball.
# We reach an end of sentence token for the hypothesis with the greatest score
# A girl in a red shirt jumps up to hit a tennis ball.
# We reach an end of sentence token for the hypothesis with the greatest score
# A girl in a red shirt leaps up to hit a tennis ball.
# We reach an end of sentence token for the hypothesis with the greatest score
# A girl in a red shirt jumping up to hit a tennis ball.
# We reach an end of sentence token for the hypothesis with the greatest score
# A girl in a red shirt is jumping up to hit a tennis ball
# We reach an end of sentence token for the hypothesis with the greatest score
# A man poses for the camera with a green crane
# We reach an end of sentence token for the hypothesis with the greatest score
# A man poses for the camera with a green crane.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man posing for the camera with a green crane.
# We reach an end of sentence token for the hypothesis with the greatest score
# A guy poses for the camera with a green crane.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man pose for the camera with a green crane.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man studies in a restaurant with another person.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man studies in a restaurant while another person watches.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man studies in a restaurant with another person on it.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man studies in a restaurant with another person on the side.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man studies in a restaurant, with another person on it.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man is loading corn on a suitcase.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man is loading corn on a suitcase courtyard.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man is loading tea into a suitcase.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man is loading tea into a suitcase courtyard
# We reach an end of sentence token for the hypothesis with the greatest score
# A man is loading tea into a suitcase courtyard.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man in a black jacket plays guitar in public.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man in a black jacket is playing guitar in public.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man in a black jacket is playing a guitar in public
# We reach an end of sentence token for the hypothesis with the greatest score
# A man in a black jacket plays guitar in the public jacket.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man in a black jacket is playing a guitar in public.
# We reach an end of sentence token for the hypothesis with the greatest score
# A dance crew at a performance during a parade
# We reach an end of sentence token for the hypothesis with the greatest score
# A dance crew at a performance during a parade.
# We reach an end of sentence token for the hypothesis with the greatest score
# A dance crew at a carnival during a parade.
# We reach an end of sentence token for the hypothesis with the greatest score
# A dance crew in China at a performance during a parade
# We reach an end of sentence token for the hypothesis with the greatest score
# A dance crew in China at a performance during a parade.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man stands on a rocky slope overlooking a body of water.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man stands on a rocky slope looking at a body of water.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man standing on a rocky slope looking at a body of water.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man is standing on a rocky slope overlooking a body of water.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man is standing on a rocky slope looking at a body of water
# We reach an end of sentence token for the hypothesis with the greatest score
# A policeman is watching a woman play from a bus.
# We reach an end of sentence token for the hypothesis with the greatest score
# A policeman is watching a woman walk up a bus.
# We reach an end of sentence token for the hypothesis with the greatest score
# A policeman is watching a woman walk out of a bus.
# We reach an end of sentence token for the hypothesis with the greatest score
# A policeman is watching a woman walk out of the bus.
# We reach an end of sentence token for the hypothesis with the greatest score
# A police officer is watching a woman walk out of a bus
# We reach an end of sentence token for the hypothesis with the greatest score
# Two middle-aged people watching a parking lot at nighttime.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two middle-aged man watching a parking lot at nighttime.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two middle-aged men watching a parking lot at nighttime.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two middle-aged people watching a parking parking lot at nighttime.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two middle-aged people watching a parking parking lot at night.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two men in blue shirts watching a soccer game.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two men in blue shirts are watching a soccer game.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two men in blue shirts look on a soccer game.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two men in blue shirts looking at a soccer game
# We reach an end of sentence token for the hypothesis with the greatest score
# Two men in blue shirts looking at a soccer game.
# We reach an end of sentence token for the hypothesis with the greatest score
# A group of men in blue uniforms stand together.
# We reach an end of sentence token for the hypothesis with the greatest score
# A group of men wearing blue uniforms stand together.
# We reach an end of sentence token for the hypothesis with the greatest score
# A group of men in blue uniforms are standing together.
# We reach an end of sentence token for the hypothesis with the greatest score
# A group of men wearing blue uniforms are standing together.
# We reach an end of sentence token for the hypothesis with the greatest score
# A group of men dressed in blue uniforms are standing together
# We reach an end of sentence token for the hypothesis with the greatest score
# A young lady doing yoga on the beach.
# We reach an end of sentence token for the hypothesis with the greatest score
# A young lady does yoga on the beach.
# We reach an end of sentence token for the hypothesis with the greatest score
# A young lady is doing yoga on the beach.
# We reach an end of sentence token for the hypothesis with the greatest score
# A young lady is practicing yoga on the beach.
# We reach an end of sentence token for the hypothesis with the greatest score
# The young lady is doing yoga on the beach.
# We reach an end of sentence token for the hypothesis with the greatest score
# A large crowd of people are standing around and some playing instruments.
# We reach an end of sentence token for the hypothesis with the greatest score
# A large crowd of people are standing around some instruments in a park.
# We reach an end of sentence token for the hypothesis with the greatest score
# A large crowd of people are standing around some instruments and some playing instruments
# We reach an end of sentence token for the hypothesis with the greatest score
# A large crowd of people are standing around some instruments and some playing instruments.
# We reach an end of sentence token for the hypothesis with the greatest score
# A large crowd of people are standing around some instruments while some playing instruments.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man wearing a balloon animal.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man wearing a balloon animal is making balloon.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man with a balloon animal animal is doing.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man wearing a balloon animal is making balloon animals
# We reach an end of sentence token for the hypothesis with the greatest score
# A man wearing a balloon animal is making balloon animals.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man barbecuing a grill on an outdoor grill.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man barbecuing over meat across a grill.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man barbecuing over meat across an outdoor grill.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man barbecuing out meat across an outdoor grill.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man barbecuing up a grill on an outdoor grill.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two men sell fruit on a fruit market.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two men sell fruits on a fruit market.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two men selling fruit on a fruit market.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two men sell the fruit on a fruit market.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two men sell some fruit on a fruit market.
# We reach an end of sentence token for the hypothesis with the greatest score
# Brunette woman in a white bikini top pouring a drink into glass
# We reach an end of sentence token for the hypothesis with the greatest score
# Brunette woman in a white bikini top pouring a drink into glass.
# We reach an end of sentence token for the hypothesis with the greatest score
# A brunette woman in a white bikini top pouring a drink into glass.
# We reach an end of sentence token for the hypothesis with the greatest score
# Brunette woman in a white bikini top pouring a drink into a glass.
# We reach an end of sentence token for the hypothesis with the greatest score
# A brown-haired woman in a white bikini top pouring a drink into glass
# We reach an end of sentence token for the hypothesis with the greatest score
# A young boy wearing sunglasses runs behind a fair.
# We reach an end of sentence token for the hypothesis with the greatest score
# A young boy wearing sunglasses is running behind a fair.
# We reach an end of sentence token for the hypothesis with the greatest score
# A young boy wearing sunglasses runs behind a fairy fair
# We reach an end of sentence token for the hypothesis with the greatest score
# A young boy wearing sunglasses runs behind a fairy fair.
# We reach an end of sentence token for the hypothesis with the greatest score
# A young boy wearing sunglasses is running behind a fairy fair
# We reach an end of sentence token for the hypothesis with the greatest score
# A hand wearing gloves holding what appears to be a wooden race.
# We reach an end of sentence token for the hypothesis with the greatest score
# A hand wearing gloves holding what appears to be a wooden pit.
# We reach an end of sentence token for the hypothesis with the greatest score
# A hand wearing gloves holding what appears to be a wooden move for a wooden move.
# We reach an end of sentence token for the hypothesis with the greatest score
# A hand wearing gloves holding what appears to be a wooden move for a wooden race.
# We reach an end of sentence token for the hypothesis with the greatest score
# A hand wearing gloves holding what seems to be a wooden move for a wooden move.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man in a plaid shirt is holding a black couple.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man in a plaid shirt is pointing a black couple.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man in a plaid shirt is showing a black couple.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man in a plaid shirt is looking at a black couple.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man in a plaid shirt is showing a black couple of people.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two men sitting on white plastic chairs in an entrance.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two men are sitting on white plastic chairs in an entrance.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two men are sitting on white plastic chairs in a doorway.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two men on white plastic chairs are sitting in an entrance.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two men on white plastic chairs are sitting in a doorway.
# We reach an end of sentence token for the hypothesis with the greatest score
# Young girl in red dress wearing a red cowboy hat.
# We reach an end of sentence token for the hypothesis with the greatest score
# Young girl in a red dress wearing a red cowboy hat.
# We reach an end of sentence token for the hypothesis with the greatest score
# A young girl in a red dress wearing a red cowboy hat.
# We reach an end of sentence token for the hypothesis with the greatest score
# A young girl in a red dress is wearing a black cowboy hat
# We reach an end of sentence token for the hypothesis with the greatest score
# A young girl in a red dress is wearing a black cowboy hat.
# We reach an end of sentence token for the hypothesis with the greatest score
# Man in white and white soccer uniform on the sidelines with a yellow and blue soccer ball.
# We reach an end of sentence token for the hypothesis with the greatest score
# Man in red and white soccer uniform on the sidelines with a yellow and blue soccer ball.
# We reach an end of sentence token for the hypothesis with the greatest score
# Man in a red and white soccer uniform on the sidelines with a yellow and blue soccer ball.
# We reach an end of sentence token for the hypothesis with the greatest score
# Man in a red and white soccer uniform on the sidelines with a yellow and blue soccer court.
# We reach an end of sentence token for the hypothesis with the greatest score
# Man in a red and white soccer uniform on the sidelines, with a yellow and blue soccer ball
# We reach an end of sentence token for the hypothesis with the greatest score
# People jumping over a hurdle on a rope.
# We reach an end of sentence token for the hypothesis with the greatest score
# People jumping over a hurdle on a tightrope.
# We reach an end of sentence token for the hypothesis with the greatest score
# People jump over a hurdle on a rope.
# We reach an end of sentence token for the hypothesis with the greatest score
# People jumping over a hurdle over a hurdle.
# We reach an end of sentence token for the hypothesis with the greatest score
# People are jumping over a hurdle on a rope.
# We reach an end of sentence token for the hypothesis with the greatest score
# People watch a marathon pass a marathon.
# We reach an end of sentence token for the hypothesis with the greatest score
# People watch as marathon passing by.
# We reach an end of sentence token for the hypothesis with the greatest score
# People watch as marathon passers pass.
# We reach an end of sentence token for the hypothesis with the greatest score
# People watch as marathon passing by going.
# We reach an end of sentence token for the hypothesis with the greatest score
# People watch as marathon passing by passing.
# We reach an end of sentence token for the hypothesis with the greatest score
# People with laptops and laptops.
# We reach an end of sentence token for the hypothesis with the greatest score
# People with laptops outside a large window.
# We reach an end of sentence token for the hypothesis with the greatest score
# People with laptops in front of a large window
# We reach an end of sentence token for the hypothesis with the greatest score
# People with laptops in front of a large window.
# We reach an end of sentence token for the hypothesis with the greatest score
# People with laptops in front of a big window.
# We reach an end of sentence token for the hypothesis with the greatest score
# A DJ is being helped by their job.
# We reach an end of sentence token for the hypothesis with the greatest score
# A DJ is being helped by their jobs.
# We reach an end of sentence token for the hypothesis with the greatest score
# A DJ is being pulled by lights while their job.
# We reach an end of sentence token for the hypothesis with the greatest score
# A DJ is being pulled by lights while onto the job.
# We reach an end of sentence token for the hypothesis with the greatest score
# A DJ is being helped by lights while onto the job.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man wearing gloves is carrying a field.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man wearing gloves is carrying corn through a field.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man wearing gloves is wearing his glove through a field.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man wearing gloves is carrying a field of dirt.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man wearing gloves is carrying a field into a field
# We reach an end of sentence token for the hypothesis with the greatest score
# This is a crowd of people in an outdoor cafe.
# We reach an end of sentence token for the hypothesis with the greatest score
# This is a man in an outdoor cafe being held by a mirror.
# We reach an end of sentence token for the hypothesis with the greatest score
# This is a woman at a cafe is being held by a mirror.
# We reach an end of sentence token for the hypothesis with the greatest score
# This is a man in an outdoor cafe is being held by a mirror.
# We reach an end of sentence token for the hypothesis with the greatest score
# This is a man in an outdoor cafe is being fed by a mirror
# We reach an end of sentence token for the hypothesis with the greatest score
# A Muslim woman holding balloons at a Muslim event.
# We reach an end of sentence token for the hypothesis with the greatest score
# A Muslim woman hold balloons at a Muslim event.
# ...
# A woman dressed in mostly black, wearing a white helmet, rides a bicycle in front of blurry trees
# We reach an end of sentence token for the hypothesis with the greatest score
# A team of bicyclists racing around the corner while others cheer nearby and take pictures.
# We reach an end of sentence token for the hypothesis with the greatest score
# A team of bicyclists racing around the corner while others cheer nearby and taking pictures.
# We reach an end of sentence token for the hypothesis with the greatest score
# A team of bicyclists racing around the corner as they cheer and take pictures.
# We reach an end of sentence token for the hypothesis with the greatest score
# A team of bicyclists drive a turn as they are cheering and take pictures.
# We reach an end of sentence token for the hypothesis with the greatest score
# A team of bicyclists racing around the corner as they cheer and taking pictures
# We reach an end of sentence token for the hypothesis with the greatest score
# Four football players in black packing a player in white.
# We reach an end of sentence token for the hypothesis with the greatest score
# Four football players in black packed around a player in white.
# We reach an end of sentence token for the hypothesis with the greatest score
# Four football players in black packed around an opposing team in white.
# We reach an end of sentence token for the hypothesis with the greatest score
# Four football players in black packing a player in white, the rain in the rain.
# We reach an end of sentence token for the hypothesis with the greatest score
# Four football players in black packing a player in white, they are in the rain.
# We reach an end of sentence token for the hypothesis with the greatest score
# A heavier tries to make the ground while  ⁇  tackles in the background.
# We reach an end of sentence token for the hypothesis with the greatest score
# A heavier tries to make the ground while  ⁇  tackles from the ground.
# We reach an end of sentence token for the hypothesis with the greatest score
# A heavier tries to make the ground while  ⁇  tackles from the ground while two friends listen.
# We reach an end of sentence token for the hypothesis with the greatest score
# A heavier tries to make the ground while  ⁇  tackles from the ground while two have owned friends.
# We reach an end of sentence token for the hypothesis with the greatest score
# A heavier tries to make the ground while  ⁇  tackles they are being tackled by two friends.
# We reach an end of sentence token for the hypothesis with the greatest score
# The basketball player in the white jersey is tackling the player in a black uniform wearing a black number.
# We reach an end of sentence token for the hypothesis with the greatest score
# The basketball player in the white jersey is tackling the player in a black uniform with the number  ⁇ . ⁇
# We reach an end of sentence token for the hypothesis with the greatest score
# The basketball player in the white uniform is tackling the player in a black uniform with the number  ⁇ . ⁇
# We reach an end of sentence token for the hypothesis with the greatest score
# The basketball player in the white uniform is tackling the player in a black uniform with the number  ⁇  on it.
# We reach an end of sentence token for the hypothesis with the greatest score
# The basketball player in the white jersey is tackling the player in a black uniform with the number  ⁇  on it.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man talking on the phone outdoors.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man talking on the phone outside.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man talking on a cellphone outdoors.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man is talking on the phone outdoors.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man is talking on the phone outside.
# We reach an end of sentence token for the hypothesis with the greatest score
# Paves of baseball players watch as they watch as they watch an opposinger.
# We reach an end of sentence token for the hypothesis with the greatest score
# Paves of baseball players watch as they watch as they walk across an opposinger.
# We reach an end of sentence token for the hypothesis with the greatest score
# Paves of baseball players watch as they watch as they walk across the opposite ends.
# We reach an end of sentence token for the hypothesis with the greatest score
# Paves of baseball players watch as they watch as they walk across an opposingor.
# We reach an end of sentence token for the hypothesis with the greatest score
# Paves of baseball players watch as they watch as they walk across the opposite ends of a referee.
# We reach an end of sentence token for the hypothesis with the greatest score
# A Obadaman is driving a steep corner in the fall.
# We reach an end of sentence token for the hypothesis with the greatest score
# A Obada shirt is driving a steep corner in the fall.
# We reach an end of sentence token for the hypothesis with the greatest score
# A Obadai officer is driving a steep corner in the fall.
# We reach an end of sentence token for the hypothesis with the greatest score
# A Obadaman is driving a steep turning through a steep corner
# We reach an end of sentence token for the hypothesis with the greatest score
# A Obadaman is driving a steep turning through a steep corner.
# We reach an end of sentence token for the hypothesis with the greatest score
#  ⁇  basketball players fighting over the ball, one in a red uniform attempt to take a ball.
# We reach an end of sentence token for the hypothesis with the greatest score
#  ⁇  basketball players fighting for the ball, one in a red jersey, one in a white uniform.
# We reach an end of sentence token for the hypothesis with the greatest score
#  ⁇  basketball players fighting for the ball, one in a red uniform, one in a white uniform.
# We reach an end of sentence token for the hypothesis with the greatest score
#  ⁇  basketball players fighting for the ball, one in a red jersey, one in a white uniform, one in a white uniform
# We reach an end of sentence token for the hypothesis with the greatest score
#  ⁇  basketball players fighting for the ball, one in a red uniform, one in a white uniform, one in a white uniform
# We reach an end of sentence token for the hypothesis with the greatest score
# A boy reaches into the air while reaching into the air.
# We reach an end of sentence token for the hypothesis with the greatest score
# A boy is reaching into the air while reaching into the air
# We reach an end of sentence token for the hypothesis with the greatest score
# A boy is reaching into the air while reaching into the air.
# We reach an end of sentence token for the hypothesis with the greatest score
# A boy reaches into the air while he is reaching into the air
# We reach an end of sentence token for the hypothesis with the greatest score
# A boy reaches into the air while he is reaching into the air.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two children in striped uniforms and black pants struggles outside a playground.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two children in striped snoamp and black pants struggles outside a playground.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two children in striped uniforms and black pants struggles outside a playground at a playground.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two children in striped snoatch and black pants struggles outside a playground.
# We reach an end of sentence token for the hypothesis with the greatest score
# Two children in striped snoamp and black pants struggles outside a playground at a playground
# We reach an end of sentence token for the hypothesis with the greatest score
# A man wearing sunglasses rides a scooter.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man in sunglasses rides a scooter.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man wearing sunglasses is riding a scooter.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man in sunglasses is riding a scooter.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man wearing sunglasses is riding on a scooter
# We reach an end of sentence token for the hypothesis with the greatest score
# A young boy in baseball gear is flipping a bat behind his head in front of his head.
# We reach an end of sentence token for the hypothesis with the greatest score
# A young boy in a baseball cap is flipping a bat behind his head in front of his head.
# We reach an end of sentence token for the hypothesis with the greatest score
# A young boy in baseball gear is flipping a bat behind his head in front of his head in front of him.
# We reach an end of sentence token for the hypothesis with the greatest score
# A young boy in a baseball cap is flipping a bat behind his head in front of his head in front of him.
# We reach an end of sentence token for the hypothesis with the greatest score
# A young boy in a baseball suit is flipping a bat behind his head in front of his head in front of him.
# We reach an end of sentence token for the hypothesis with the greatest score
# Six men are sitting on a block with wooden crates.
# We reach an end of sentence token for the hypothesis with the greatest score
# Six men are sitting on a tree field with wooden boxs.
# We reach an end of sentence token for the hypothesis with the greatest score
# Six men are sitting on a wooden block with wood boxs.
# We reach an end of sentence token for the hypothesis with the greatest score
# Six men are sitting on a tree field with wooden crates.
# We reach an end of sentence token for the hypothesis with the greatest score
# Six men are sitting on a wooden block with wooden crates.
# We reach an end of sentence token for the hypothesis with the greatest score
# A brown dog picks up a branched surface.
# We reach an end of sentence token for the hypothesis with the greatest score
# A brown dog is lifting a branched surface.
# We reach an end of sentence token for the hypothesis with the greatest score
# A brown dog is lifting a block of dirt.
# We reach an end of sentence token for the hypothesis with the greatest score
# A brown dog is picking up a branched surface.
# We reach an end of sentence token for the hypothesis with the greatest score
# A brown dog is lifting a block of dirt around a track.
# We reach an end of sentence token for the hypothesis with the greatest score
# The man in yellow is holding a brown horse.
# We reach an end of sentence token for the hypothesis with the greatest score
# The man in yellow is holding a brown horse on a leash
# We reach an end of sentence token for the hypothesis with the greatest score
# The man in yellow is holding a brown horse on a leash.
# We reach an end of sentence token for the hypothesis with the greatest score
# The man in yellow is holding a brown horse on leashes.
# We reach an end of sentence token for the hypothesis with the greatest score
# The man in yellow is holding a brown horse on the leash.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man in a white shirt and apron is opening a bird.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man in a white shirt and apron is carving a bird.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man in a white shirt and apron is caught a bird.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man in a white shirt and apron is shown a bird.
# We reach an end of sentence token for the hypothesis with the greatest score
# A man in a white shirt and apron is cleaning a bird.
# We reach an end of sentence token for the hypothesis with the greatest score
# An elderly woman is cooking in a wok.
# We reach an end of sentence token for the hypothesis with the greatest score
# An elderly woman is cooking on a wok in the outdoors.
# We reach an end of sentence token for the hypothesis with the greatest score
# An elderly woman is cooking in a wool for sale outdoors.
# We reach an end of sentence token for the hypothesis with the greatest score
# An elderly woman is cooking in a wool for sale outside.
# We reach an end of sentence token for the hypothesis with the greatest score
# An elderly woman is cooking in a wool for sale in a wool.
# We reach an end of sentence token for the hypothesis with the greatest score
# Marathon runners walk down a city street while others stand around them.
# We reach an end of sentence token for the hypothesis with the greatest score
# Marathon women walk down a city street while others stand around them.
# We reach an end of sentence token for the hypothesis with the greatest score
# Marathon runners walking down a city street while others stand around them.
# We reach an end of sentence token for the hypothesis with the greatest score
# Marathon runners walk down a city street while others are standing around them.
# We reach an end of sentence token for the hypothesis with the greatest score
# Marathon runners walking down a city street while others are standing around them.
# We reach an end of sentence token for the hypothesis with the greatest score
# Young Asian woman wearing a sunhat rides a bicycle.
# We reach an end of sentence token for the hypothesis with the greatest score
# Young Asian woman wears a sunhat on a bicycle.
# We reach an end of sentence token for the hypothesis with the greatest score
# Young Asian woman wearing a sunhat rides a bicycle ride.
# We reach an end of sentence token for the hypothesis with the greatest score
# Young Asian woman wearing a sunhats riding a bicycle.
# We reach an end of sentence token for the hypothesis with the greatest score
# Young Asian woman wears a sunhat to riding a bicycle
# We reach an end of sentence token for the hypothesis with the greatest score
# Some children are outside playing with two trees on the ground.
# We reach an end of sentence token for the hypothesis with the greatest score
# Some children are outside playing on the ground while playing two trees.
# We reach an end of sentence token for the hypothesis with the greatest score
# Some children are outside playing on the ground and playing two trees.
# We reach an end of sentence token for the hypothesis with the greatest score
# Some children are outside playing on the ground and playing the ground.
# We reach an end of sentence token for the hypothesis with the greatest score
# Some children are outside playing with two trees on the floor by two trees
# We reach an end of sentence token for the hypothesis with the greatest score
# An older man plays a video game.
# We reach an end of sentence token for the hypothesis with the greatest score
# An older man playing a video game.
# We reach an end of sentence token for the hypothesis with the greatest score
# An older man is playing a video game.
# We reach an end of sentence token for the hypothesis with the greatest score
# An older man playing a game of video game
# We reach an end of sentence token for the hypothesis with the greatest score
# An older man playing a game of video game.
# We reach an end of sentence token for the hypothesis with the greatest score
# Girl on a shoreline with a mountain in the background.
# We reach an end of sentence token for the hypothesis with the greatest score
# A girls on a shoreline with a mountain in the background.
# We reach an end of sentence token for the hypothesis with the greatest score
# A girl on a shore with a mountain in the background.
# We reach an end of sentence token for the hypothesis with the greatest score
# A young girl on a shore with a mountain in the background
# We reach an end of sentence token for the hypothesis with the greatest score
# A young girl on a shore with a mountain in the background.
# Finished writing predictions to seq2seq_predictions_attention.json.

# %% [markdown]
# # Experimentation: 1-Page Report
#
# Now it's time for you to experiment.  Try to improve the denotation accuracy on the validation set further. Feel free to modify the code above directly or copy it in new cells below.
#
# Here are some ideas to try out:
# * **Back translation**: Since the training dataset is small, another strategy for improving performance might be to generate more training instances. One popular technique people used in machine translation is called back translation(https://arxiv.org/abs/1808.07512). Train another model from English to Gernman and consturct more data.
#
# * **Word embeddings**: You can try initializing the input word embeddings with [Glove vectors](https://nlp.stanford.edu/projects/glove/). You should try both finetuning these embeddings or keeping them fixed.
# * **Regularization**: You can also try some of the regularization techniques we tried in the language modeling assignment, however these may or may not help.
# * **Tokenization**: Exploring with how tokenization is done or how big vocabulary size is can also be helpful. We used unigram language model subword tokenization and use a vocabulary of size 8000. You can consider using BPE (a very popular tokenization technique) or using characters or even some others.
# * **Hyperparameter tuning**: Finally you can try playing around with hyperparameters to see if there is a better configuration than what we have provided (we only did a modest amount of tuning).
#
# For this section, you will submit a write-up describing the extensions and/or modifications that you tried.  Your write-up should be **1-page maximum** in length and should be submitted in PDF format.  You may use any editor you like, but we recommend using LaTeX and working in an environment like Overleaf.
# For full credit, your write-up should include:
# 1.   A concise and precise description of the extension that you tried.
# 2.   A motivation for why you believed this approach might improve your model.
# 3.   A discussion of whether the extension was effective and/or an analysis of the results.  This will generally involve some combination of tables, learning curves, etc.
# 4.   A bottom-line summary of your results comparing the scores of your improvement to the original model.
# The purpose of this exercise is to experiment, so feel free to try/ablate multiple of the suggestions above as well as any others you come up with!
# When you submit the file, please name it `report.pdf`.

# %%
### For the improvement:
# If you implemented your own improvements, submit the predictions using that model on the test data instead:
# generate_predictions_file_for_submission("seq2seq_predictions_attention.json", improved_model, test_data, "beam", batch_size=1)

# %% [markdown]
# ### Submission
#
# Upload a submission with the following files to Gradescope:
# * proj_3.ipynb (rename to match this exactly)
# * seq2seq_predictions_baseline.json (baseline_model with greedy decoding would suffice)
# * seq2seq_predictions_attention.json (if you have an improved model, use that model to generate this file, otherwise submiting attention model with greedy decoding will get you full points (20%) but probably not for the improvement evaluation (10%))
# * beam_seqs.json
# * report.pdf
#
# You can upload files individually or as part of a zip file, but if using a zip file be sure you are zipping the files directly and not a folder that contains them.
#
# Be sure to check the output of the autograder after it runs.  It should confirm that no files are missing and that the output files have the correct format.  Note that the test set accuracies shown by the autograder are on different data from your validation set.  We will compare your score on the test set to our model's score and assign points based on that.
